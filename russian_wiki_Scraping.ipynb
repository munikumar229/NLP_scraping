# %%
from google.colab import drive
from google.colab import files
import time
import os
import requests
from zipfile import ZipFile
import shutil


# Mount Google Drive to temporarily store files
from google.colab import drive
drive.mount('/content/drive')

def fetch_wikipedia_page(title, lang='ru'):
    """
    Fetch a Wikipedia page content using the Wikipedia API.

    Args:
    - title: Title of the Wikipedia page (in Russian).
    - lang: Language of Wikipedia to fetch data from (default: 'ru' for Russian).

    Returns:
    - A string containing the page content, or None if the page is not found.
    """
    url = f'https://{lang}.wikipedia.org/w/api.php'

    params = {
        'action': 'query',
        'format': 'json',
        'prop': 'extracts',
        'explaintext': True,
        'titles': title
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        pages = data['query']['pages']
        page = next(iter(pages.values()))  # Get the first (and only) page result

        if 'extract' in page:
            return page['extract']
        else:
            return None
    else:
        return None

def save_page_content(title, content, folder):
    """
    Save the Wikipedia page content to a .txt file named after the title.

    Args:
    - title: Title of the Wikipedia page.
    - content: Text content to be saved.
    - folder: Folder where the .txt file will be saved.
    """
    # Replace special characters that could interfere with filenames
    safe_title = title.replace("/", "_").replace("\\", "_")
    file_path = os.path.join(folder, f"{safe_title}.txt")

    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(content)

    # Get the file size in kilobytes (KB)
    file_size = os.path.getsize(file_path) / 1024  # Convert to KB
    print(f"Saved '{title}' with size {file_size:.2f} KB")

def scrape_wikipedia_titles(titles, folder):
    """
    Scrape a list of Wikipedia titles and save their content to text files.

    Args:
    - titles: List of Wikipedia page titles to scrape.
    - folder: Folder where the .txt files will be saved.
    """
    if not os.path.exists(folder):
        os.makedirs(folder)  # Create folder if it doesn't exist

    # Get the list of existing files
    existing_files = {file.replace(".txt", "") for file in os.listdir(folder)}

    for title in titles:
        # Skip the title if it already exists
        if title in existing_files:
            print(f"Skipping '{title}' (already exists)")
            continue

        content = fetch_wikipedia_page(title)
        if content:
            save_page_content(title, content, folder)
def generate_random_titles(num_titles=20000, lang='ru'):
    """
    Fetch a list of random Wikipedia page titles from the given language Wikipedia.

    Args:
    - num_titles: Number of random titles to fetch.
    - lang: Language code for Wikipedia (default is 'ru' for Russian).

    Returns:
    - List of random Wikipedia titles.
    """
    titles = []
    url = f'https://{lang}.wikipedia.org/w/api.php'

    for _ in range(num_titles // 50):  # Wikipedia's API provides up to 50 random titles per request
        params = {
            'action': 'query',
            'format': 'json',
            'list': 'random',
            'rnlimit': 50,
            'rnnamespace': 0  # Limit to main namespace (articles only)
        }

        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            random_titles = [item['title'] for item in data['query']['random']]
            titles.extend(random_titles)

    # Return unique titles to avoid duplicates
    return list(set(titles))

# Main script execution
if __name__ == "__main__":
    # Generate 3000 unique random Russian Wikipedia titles2
     random_titles = generate_random_titles(0000)

    # Define Google Drive folder for temporary storage
    output_folder = "/content/drive/My Drive/wikipedia_ru_data_temp_103s"

    # Scrape the pages and save the content (skipping already existing titles)
    scrape_wikipedia_titles(random_titles, output_folder)

    # Zip the folder to prepare for download
    shutil.make_archive('wikipedia_ru_data_temp_103s', 'zip', output_folder)

    # Download the zipped folder to your local machine
    from google.colab import files
    files.download('wikipedia_ru_data_temp_103s.zip')
# Out:
# Streaming output truncated to the last 5000 lines.
# Saved 'Корягино' with size 2.67 KB
# Saved 'Хоз, Дов' with size 8.90 KB
# Saved 'Гироскутер' with size 9.88 KB
# Saved 'Сибирь (спичечная фабрика)' with size 11.58 KB
# Saved 'Rally Driver' with size 5.27 KB
# Saved 'Thaicom 8' with size 4.67 KB
# Saved 'Макраи, Каталин' with size 1.74 KB
# Saved 'Трисахариды' with size 2.31 KB
# Saved 'Ласерда, Франсишку де' with size 3.71 KB
# Saved 'Брашов-Гимбав (аэропорт)' with size 5.12 KB
# Saved 'Обох' with size 0.43 KB
# Saved 'Палестиноведение' with size 13.46 KB
# Saved 'Ефремово (Рамешковский район)' with size 2.19 KB
# Saved 'Спрингхолл, Дейв' with size 4.67 KB
# Saved 'Сигизмунд Август в виленском саду' with size 0.72 KB
# Saved 'Завроподоморфы' with size 8.81 KB
# Saved 'Коляницы' with size 1.81 KB
# Saved 'Бойс, Кэмерон' with size 4.59 KB
# Saved 'Цзян Цичэнь' with size 3.08 KB
# Saved 'Теннис на летних Олимпийских играх 2024 — мужской парный турнир' with size 2.11 KB
# Saved 'Фотосинтетически активная радиация' with size 18.75 KB
# Saved 'Папаяннис' with size 0.69 KB
# Saved 'Пролетарка (Оренбургская область)' with size 2.48 KB
# Saved 'Улица Кузнецова' with size 3.02 KB
# Saved 'Сюльский' with size 0.29 KB
# Saved 'Павловский, Иван Григорьевич (генерал)' with size 19.43 KB
# Saved 'Шуб, Игорь Дмитриевич' with size 7.46 KB
# Saved '«Сибиряк» в сезоне 2012/2013' with size 8.45 KB
# Saved 'Саломонссон, Эмиль' with size 3.63 KB
# Saved 'МАЗ-6310' with size 1.96 KB
# Saved 'Batrachuperus cochranae' with size 0.87 KB
# Saved 'Ницовкра (Лакский район)' with size 2.42 KB
# Saved 'Восточная Фризия' with size 6.98 KB
# Saved 'Twilight of the Thunder God' with size 1.00 KB
# Saved 'Коста-Рика на летних Олимпийских играх 2012' with size 0.67 KB
# Saved 'Йован-Инован, Сония' with size 1.52 KB
# Saved 'Волконский, Михаил Николаевич' with size 10.65 KB
# Saved 'Красноозерный' with size 0.35 KB
# Saved 'Шелестов' with size 0.41 KB
# Saved 'Старкова' with size 0.67 KB
# Saved 'Кудринская (Верховажский район)' with size 1.11 KB
# Saved 'Тиллар (Арканзас)' with size 3.98 KB
# Saved 'Sonic Adventure' with size 66.67 KB
# Saved 'Изотропный вектор' with size 10.05 KB
# Saved 'Оссовский, Пётр Степанович' with size 3.55 KB
# Saved 'Пимон, Жерар де Вьен' with size 2.82 KB
# Saved 'Попов, Андрей Александрович (этнолог)' with size 3.35 KB
# Saved 'Руфф, Алида' with size 2.10 KB
# Saved 'Лакретель' with size 0.61 KB
# Saved 'Кон, Марта' with size 6.57 KB
# Saved 'Порядневщина' with size 1.02 KB
# Saved 'Энрике I (король Кастилии)' with size 1.22 KB
# Saved 'Великий Двор (Бокситогорский район)' with size 6.08 KB
# Saved 'Александровский муниципальный округ (Пермский край)' with size 9.44 KB
# Saved 'Чемпионат СССР по лыжным гонкам 1961' with size 0.69 KB
# Saved 'Лотта (МАПП)' with size 1.89 KB
# Saved 'Замораживание орбитального момента' with size 6.37 KB
# Saved 'Мамсуров, Саханджери Гидзоевич' with size 3.61 KB
# Saved 'Кахала (Эстония)' with size 3.09 KB
# Saved 'Вальчета (департамент)' with size 1.20 KB
# Saved 'Маген, Цви' with size 2.21 KB
# Saved 'Панченко, Пимен Емельянович' with size 9.98 KB
# Saved 'Цой, Павел Николаевич' with size 4.59 KB
# Saved 'Кузнецов, Никита Александрович' with size 5.32 KB
# Saved 'Холон (город)' with size 12.44 KB
# Saved 'Colma' with size 2.88 KB
# Saved 'Антоновичи (Смоленская область)' with size 1.09 KB
# Saved 'Куштеппа' with size 0.89 KB
# Saved 'Кислово (Сергинское сельское поселение)' with size 2.11 KB
# Saved 'Маршак, Александр' with size 0.25 KB
# Saved 'Тюнсет' with size 0.85 KB
# Saved 'Парламентские выборы в Испании (1967)' with size 2.94 KB
# Saved 'Коксовый газ' with size 3.71 KB
# Saved 'Мюллер, Фридрих (веймарский канцлер)' with size 0.98 KB
# Saved 'Лиофилизация' with size 4.86 KB
# Saved 'Борщёв, Тимофей Михайлович' with size 16.41 KB
# Saved 'Соглядатай' with size 13.74 KB
# Saved 'Малые Пищевицы' with size 0.64 KB
# Saved 'Карасу (Аджикабульский район)' with size 3.92 KB
# Saved 'Хойбергер, Рихард' with size 1.08 KB
# Saved 'Неом (значения)' with size 0.26 KB
# Saved 'Первомайский (Привокзальный территориальный округ)' with size 1.02 KB
# Saved 'Архиепархия Сальты' with size 3.80 KB
# Saved 'ДФ-120 «Днепр»' with size 6.61 KB
# Saved '412-й гвардейский гаубичный артиллерийский полк' with size 1.47 KB
# Saved 'Пилас' with size 0.95 KB
# Saved 'Дворски, Петер' with size 9.31 KB
# Saved 'Бочановка (Тверская область)' with size 0.54 KB
# Saved 'Злобина, Дина Дмитриевна' with size 5.70 KB
# Saved 'Хелмонд (значения)' with size 0.62 KB
# Saved 'Даньковка (Черниговская область)' with size 1.40 KB
# Saved 'Симптом Джейнуэя' with size 1.21 KB
# Saved 'Улдуз (станция метро)' with size 4.22 KB
# Saved 'Mercedes-Benz W125 Rekordwagen' with size 6.47 KB
# Saved 'Долгота дня' with size 8.67 KB
# Saved 'Eomeropidae' with size 1.46 KB
# Saved 'Кичин, Валерий Семёнович' with size 11.30 KB
# Saved 'Булдаков, Алексей' with size 0.29 KB
# Saved 'Хинголи' with size 0.66 KB
# Saved 'ВЛ12' with size 7.57 KB
# Saved 'Жизненно необходимые и важнейшие лекарственные препараты' with size 7.82 KB
# Saved 'Чодраял (Иштымбальское сельское поселение)' with size 3.68 KB
# Saved 'Павлик, Филип' with size 2.10 KB
# Saved 'Владимировка (Касторенский район)' with size 2.66 KB
# Saved 'Медаль «За албанскую экспедицию»' with size 6.46 KB
# Saved 'Лаврентий (монах)' with size 2.14 KB
# Saved 'Прокуна, Алехандра' with size 3.05 KB
# Saved 'Бархед № 11' with size 10.19 KB
# Saved 'Гилберт де Брионн' with size 6.23 KB
# Saved 'Alloberberis' with size 1.81 KB
# Saved 'Уэст-Форк (река)' with size 6.16 KB
# Saved 'Малый фигурный клит' with size 0.76 KB
# Saved 'Никонов, Иван' with size 0.26 KB
# Saved 'Добелиньская-Элишевская, Тереза' with size 2.95 KB
# Saved 'Симанский (посёлок)' with size 0.81 KB
# Saved 'Остров Крузенштерна' with size 5.94 KB
# Saved 'Международный футбольный турнир на Мальте' with size 1.09 KB
# Saved 'Vought SB2U Vindicator' with size 1.93 KB
# Saved 'Озерова, Нина Даниловна' with size 1.08 KB
# Saved 'Буффемон' with size 0.49 KB
# Saved 'Ultra 24' with size 1.15 KB
# Saved 'Тихомиров, Геннадий Александрович' with size 0.83 KB
# Saved 'Чемпионат Польши по футболу 1962/1963' with size 0.60 KB
# Saved 'Grand Theft Auto: XXX Parody' with size 2.44 KB
# Saved 'Собор Святого Николая (Грайфсвальд)' with size 2.03 KB
# Saved 'Nevermore (значения)' with size 0.65 KB
# Saved 'Быченский, Иван Тимофеевич (старший)' with size 4.54 KB
# Saved 'Breguet Aviation' with size 17.57 KB
# Saved 'Американское Самоа (значения)' with size 0.48 KB
# Saved 'Тельгате' with size 0.83 KB
# Saved 'Раух, Генри' with size 3.65 KB
# Saved 'Дробышев, Алексей Юрьевич' with size 4.94 KB
# Saved 'AT&T Tennis Challenge' with size 3.79 KB
# Saved '4-й округ департамента Кальвадос' with size 0.96 KB
# Saved 'Халлер' with size 1.34 KB
# Saved 'Эквифокальная гиперповерхность' with size 0.90 KB
# Saved 'Александров, Сергей Николаевич (инженер)' with size 3.73 KB
# Saved 'Фуа (замок)' with size 2.77 KB
# Saved 'Бревард (округ)' with size 3.79 KB
# Saved 'Егоров, Борис Ефимович' with size 5.92 KB
# Saved 'The Campfire Headphase' with size 1.04 KB
# Saved 'Баншкхали' with size 0.80 KB
# Saved 'Афинский Акрополь' with size 6.87 KB
# Saved 'Явное' with size 0.64 KB
# Saved 'Перевёртка ЦРУ' with size 3.90 KB
# Saved 'Gametis' with size 1.99 KB
# Saved 'Яуза (значения)' with size 1.48 KB
# Saved 'Барсуки (Горецкий район)' with size 0.75 KB
# Saved 'Лапухин, Василий Захарьевич' with size 5.34 KB
# Saved 'Давыдовка (Тамбовская область)' with size 2.17 KB
# Saved 'Задержание' with size 7.39 KB
# Saved 'Долец' with size 0.17 KB
# Saved 'Дождь, Сергей' with size 11.60 KB
# Saved 'Пулитцеровская премия 2015 года' with size 9.62 KB
# Saved 'Дельбос, Ивон' with size 4.19 KB
# Saved 'Христианство в Бурунди' with size 6.64 KB
# Saved 'Сражение за Ле-Ман (1793)' with size 4.82 KB
# Saved 'Окно Эймса' with size 3.59 KB
# Saved 'НБЛ в сезоне 1939/1940' with size 2.08 KB
# Saved 'Левенда' with size 1.37 KB
# Saved 'Densetsu Kyojin Ideon' with size 37.02 KB
# Saved 'Святой Николай (линейный корабль, 1748)' with size 7.88 KB
# Saved 'Росси, Джованни Франческо' with size 5.07 KB
# Saved 'The American Dream' with size 1.23 KB
# Saved 'Альмен, Рут' with size 3.40 KB
# Saved 'Касян, Андрей Филиппович' with size 4.86 KB
# Saved 'Хот-род' with size 4.16 KB
# Saved 'Боровский, Ярослав Евгеньевич' with size 2.91 KB
# Saved 'Список экзопланет, открытых проектом HATNet' with size 1.34 KB
# Saved 'Баратова, Изабелла Григорьевна' with size 2.26 KB
# Saved 'Aggressive phonk' with size 2.26 KB
# Saved 'Осека (Брестская область)' with size 2.07 KB
# Saved 'Ригамонти, Антонио' with size 2.02 KB
# Saved 'Куприянов, Валерий Николаевич' with size 6.57 KB
# Saved 'Чемпионат Южной Америки по волейболу среди мужчин 1969' with size 2.78 KB
# Saved 'Инчкит' with size 5.27 KB
# Saved 'Тимбики' with size 3.12 KB
# Saved 'Вешние воды' with size 9.44 KB
# Saved 'Остролодочник нижнеальпийский' with size 3.31 KB
# Saved 'Клюг, Фердинанд' with size 1.70 KB
# Saved 'Кара-Суу (Кочкорский район)' with size 1.43 KB
# Saved 'Stenodema holsata' with size 4.42 KB
# Saved 'Мурьель, Луис' with size 1.81 KB
# Saved 'Лольо, Лусиано' with size 2.30 KB
# Saved 'Гней Тремеллий Флакк' with size 1.52 KB
# Saved 'Лосевка (Клетнянский район)' with size 2.37 KB
# Saved 'Спратлен, Памела' with size 7.41 KB
# Saved 'Кефалиния (значения)' with size 0.26 KB
# Saved 'Европейское пресс-фотоагентство' with size 6.62 KB
# Saved 'Буонаюти, Телемако' with size 2.32 KB
# Saved 'Кликитаты' with size 1.90 KB
# Saved 'Тумья' with size 0.87 KB
# Saved 'Шаапиванский собор' with size 3.78 KB
# Saved 'Бута-Буте (значения)' with size 0.21 KB
# Saved 'Кузеево (Балтачевский район)' with size 0.86 KB
# Saved 'Снегирь' with size 11.84 KB
# Saved 'Зелёная Роща (Кромской район)' with size 2.33 KB
# Saved 'Цховребадзе, Георгий' with size 2.03 KB
# Saved 'Гэмбрилл, Майкл' with size 1.01 KB
# Saved 'Бьюгн' with size 0.84 KB
# Saved 'Солнечное опреснение' with size 4.90 KB
# Saved 'Донское сельское поселение (Орловский район)' with size 3.08 KB
# Saved 'Война короля Вильгельма' with size 7.75 KB
# Saved 'Стрепетов (посёлок)' with size 0.62 KB
# Saved 'К-472' with size 4.68 KB
# Saved 'Dubrovnik Airline' with size 2.19 KB
# Saved 'Бодров, Иван Яковлевич' with size 3.68 KB
# Saved 'Сортировочная улица (Екатеринбург)' with size 3.19 KB
# Saved 'Лесогорский' with size 9.51 KB
# Saved 'Алушта — Судак — Феодосия (автодорога)' with size 7.51 KB
# Saved 'Браун, Джейлен' with size 10.71 KB
# Saved 'Ростовская государственная филармония' with size 6.58 KB
# Saved 'Мартынов, Виктор Владимирович (лингвист)' with size 19.57 KB
# Saved 'Смит, Роберт' with size 1.00 KB
# Saved 'Равно-Поле' with size 1.30 KB
# Saved 'Административное деление Доминиканской Республики' with size 0.13 KB
# Saved 'Буддеус, Аурелио' with size 4.21 KB
# Saved 'Апарима' with size 1.82 KB
# Saved 'ТЭП80' with size 36.22 KB
# Saved 'Булацель, Иван Михайлович' with size 4.61 KB
# Saved 'Женская сборная Норвегии по футболу (до 17 лет)' with size 0.73 KB
# Saved 'Чувашская вышивка' with size 6.75 KB
# Saved 'Атаханова, Кайша Якубовна' with size 4.19 KB
# Saved 'Северо-восточный помо' with size 0.73 KB
# Saved 'Tear in My Heart' with size 5.44 KB
# Saved 'Орден Святого Николая (значения)' with size 1.16 KB
# Saved 'Вазеринское' with size 0.52 KB
# Saved 'Ростовцев, Николай Яковлевич' with size 13.81 KB
# Saved 'Кипчирчир, Алекс' with size 1.90 KB
# Saved 'Тактический фонарь' with size 9.51 KB
# Saved 'Atheta giguereae' with size 2.34 KB
# Saved 'Файрбрейс, Айзая' with size 3.40 KB
# Saved 'Иловай-Рождественское' with size 2.58 KB
# Saved 'Кюрелам' with size 2.28 KB
# Saved 'Луций Атилий (претор)' with size 1.13 KB
# Saved 'Косяк Саргина' with size 8.30 KB
# Saved 'Корралес' with size 1.41 KB
# Saved 'CC Волос Вероники' with size 1.98 KB
# Saved 'Перестрелка в Уэйко' with size 16.35 KB
# Saved 'Первокурсник (фильм, 1925)' with size 0.84 KB
# Saved 'Ждановская волость' with size 0.85 KB
# Saved 'Трапаидзе, Алфесий Семёнович' with size 4.03 KB
# Saved 'Мезенская Пижма' with size 2.73 KB
# Saved 'Бэнкс, Эрни' with size 41.63 KB
# Saved 'Медаль «За усердие» (Минюст России)' with size 10.47 KB
# Saved 'Диас, Аледмис' with size 7.46 KB
# Saved 'Диакону, Мадалина' with size 28.42 KB
# Saved 'Ташетканы' with size 0.68 KB
# Saved 'Scope Group' with size 4.91 KB
# Saved 'Код-шеринг' with size 2.46 KB
# Saved '(1762) Расселл' with size 0.75 KB
# Saved 'Саттаров, Гумар Фаизович' with size 7.76 KB
# Saved 'Бустинса Кабала, Леонор' with size 3.68 KB
# Saved 'Бенаб' with size 1.42 KB
# Saved 'Валмайор' with size 0.78 KB
# Saved 'Муромская икона Божией Матери' with size 4.16 KB
# Saved 'Глушкевич, Мариан Феофилович' with size 2.72 KB
# Saved 'Башкортостан в эпоху Ногайской Орды' with size 24.12 KB
# Saved 'Карбинци (община)' with size 1.92 KB
# Saved 'Залужье (Духовщинский район)' with size 0.99 KB
# Saved 'Янкович, Нина' with size 4.98 KB
# Saved 'Зингаревич, Борис Геннадьевич' with size 5.44 KB
# Saved 'Лугвен' with size 2.32 KB
# Saved 'Индийско-тонганские отношения' with size 11.30 KB
# Saved 'Список политических партий Кот-д’Ивуара' with size 1.37 KB
# Saved 'Воинское кладбище № 60 (Магура)' with size 2.95 KB
# Saved 'Черёмушское сельское поселение' with size 4.00 KB
# Saved 'Лемланд' with size 1.14 KB
# Saved 'Василевка (Попельнянский район)' with size 0.97 KB
# Saved 'Кулду' with size 1.03 KB
# Saved 'Борисов, Семён' with size 0.53 KB
# Saved 'Родийалюминий' with size 1.14 KB
# Saved 'Выдра, Матей' with size 4.71 KB
# Saved 'Дорогу Нодди' with size 6.96 KB
# Saved 'Осенево (Ярославская область)' with size 3.51 KB
# Saved 'Хиган' with size 5.49 KB
# Saved 'Государственное устройство Кабо-Верде' with size 13.38 KB
# Saved 'Спремо, Милан' with size 0.72 KB
# Saved 'Шарп, Джейн' with size 1.25 KB
# Saved 'Егоршев, Андрей Анатольевич' with size 2.03 KB
# Saved 'Тшцель (гмина)' with size 0.92 KB
# Saved 'Долль, Томас' with size 7.31 KB
# Saved 'Сосна остистая' with size 2.41 KB
# Saved 'Чемпионат мира по танковому биатлону 2021' with size 5.61 KB
# Saved 'Мокроусово (Ярославская область)' with size 2.54 KB
# Saved 'Абкаларкуль' with size 1.02 KB
# Saved 'Опалихино (Пермский край)' with size 1.82 KB
# Saved 'Остров Скрыплёва' with size 4.16 KB
# Saved 'Подсолнечное масло' with size 21.78 KB
# Saved 'Ганзейский Парламент' with size 5.03 KB
# Saved 'Калининский (Зианчуринский район)' with size 0.68 KB
# Saved 'Сун Цзывэнь' with size 5.53 KB
# Saved 'Солонечно-Талое' with size 28.48 KB
# Saved 'Пакетт, Ричард' with size 24.73 KB
# Saved 'Шейнин, Лев Романович' with size 52.95 KB
# Saved 'Золотой хет-трик' with size 16.45 KB
# Saved 'Унгвентарий' with size 3.35 KB
# Saved 'Жегусов, Иван Пудович' with size 2.84 KB
# Saved 'Чарлстон-Парк (Флорида)' with size 4.37 KB
# Saved 'Макаренков, Николай Петрович' with size 1.70 KB
# Saved 'Арну, Шарль' with size 2.61 KB
# Saved 'Динев' with size 0.75 KB
# Saved 'Лессинг, Карл Фридрих' with size 6.42 KB
# Saved 'Рахим, Джалалудин Абдур' with size 7.09 KB
# Saved 'Долгово (Пучежский район)' with size 2.43 KB
# Saved 'Дебесай, Якоб' with size 3.72 KB
# Saved 'Соколаев, Владимир Анатольевич' with size 31.81 KB
# Saved 'Полоцкий кадетский корпус' with size 14.78 KB
# Saved 'Трагуларии' with size 1.65 KB
# Saved 'Бадам 2' with size 0.74 KB
# Saved 'Hakea rostrata' with size 2.61 KB
# Saved 'Эгген, Дан' with size 2.17 KB
# Saved 'Сельское поселение «Деревня Маслово»' with size 1.41 KB
# Saved 'Madden NFL 2004' with size 3.63 KB
# Saved 'Дювин, Джозеф' with size 21.69 KB
# Saved 'Карманово (платформа)' with size 2.86 KB
# Saved 'Нургалиева, Алёна Сабиржановна' with size 1.95 KB
# Saved 'Шовут' with size 1.13 KB
# Saved 'Лихота, Алина Александровна' with size 1.98 KB
# Saved 'Кике Сан-Мартин' with size 3.40 KB
# Saved 'Шоу, Артур' with size 0.65 KB
# Saved 'Смешанная команда на летних Олимпийских играх 1896' with size 0.90 KB
# Saved 'Четонов, Алексей Семёнович' with size 3.19 KB
# Saved 'Реньер' with size 0.37 KB
# Saved 'Соты (геометрия)' with size 11.05 KB
# Saved 'Асири, Тошходжа' with size 2.69 KB
# Saved 'Князевы (деревня)' with size 0.88 KB
# Saved 'Чемпионат Испании по футболу 1964/1965' with size 1.67 KB
# Saved 'Меде' with size 0.73 KB
# Saved 'K2-171' with size 1.09 KB
# Saved 'Велдховен, Чарльз' with size 3.73 KB
# Saved 'Яворский замок Пястов' with size 3.87 KB
# Saved 'Скарфьотти, Лудовико' with size 4.75 KB
# Saved 'Нили (значения)' with size 0.72 KB
# Saved 'Освобождение (фильм, 1940)' with size 5.87 KB
# Saved 'Грейспойнт' with size 6.02 KB
# Saved 'Opel Moonlight Roadster' with size 1.09 KB
# Saved 'Дарение' with size 5.74 KB
# Saved 'Кастельянос, Хуан де' with size 3.30 KB
# Saved 'Модебадзе, Нодар Арчилович' with size 1.61 KB
# Saved 'Юйс, Питер' with size 3.45 KB
# Saved 'Баженовка (Самарская область)' with size 36.09 KB
# Saved 'Пасека (Житковичский район)' with size 2.65 KB
# Saved 'Рогачиха' with size 0.50 KB
# Saved 'Князевка (Северо-Казахстанская область)' with size 0.89 KB
# Saved 'Июнь 2019 года' with size 14.00 KB
# Saved 'Это мы (5-й сезон)' with size 1.75 KB
# Saved 'Туркменский календарь' with size 4.07 KB
# Saved 'Pentangle' with size 12.43 KB
# Saved 'Негарь' with size 1.53 KB
# Saved 'Шайтанка (приток Мокрых Ялов)' with size 1.48 KB
# Saved 'Tyla (альбом)' with size 3.19 KB
# Saved 'Пшибыльский, Вацлав' with size 2.09 KB
# Saved 'Борисовка (Новгородская область)' with size 6.07 KB
# Saved 'Ваальбара' with size 3.70 KB
# Saved 'Unreal' with size 0.90 KB
# Saved 'География Йемена' with size 12.05 KB
# Saved 'Саконнакхон (провинция)' with size 2.85 KB
# Saved 'Белозорье' with size 2.20 KB
# Saved 'Прекульский район' with size 1.20 KB
# Saved 'Филиппов, Валерий Николаевич' with size 0.37 KB
# Saved 'Гудимов, Павел Владимирович' with size 11.17 KB
# Saved 'Фиби и единорог' with size 4.22 KB
# Saved 'Лоу, Онанди' with size 13.19 KB
# Saved 'Валдаймс, Занис' with size 4.84 KB
# Saved 'Стаффорд, Генри, 2-й барон Стаффорд' with size 3.70 KB
# Saved 'Банда Валерия Басенко' with size 26.30 KB
# Saved 'Бенальо' with size 2.11 KB
# Saved 'City Burials' with size 5.45 KB
# Saved 'Tchibo' with size 5.96 KB
# Saved 'Рабочая партия Курдистана' with size 19.25 KB
# Saved 'Венец (община)' with size 0.59 KB
# Saved 'Колтовской, Иван Александрович' with size 4.06 KB
# Saved 'Герб Баня-Луки' with size 14.33 KB
# Saved 'Гудолл, Дэвид' with size 3.75 KB
# Saved 'Генерал-полковник НОАК' with size 6.45 KB
# Saved 'Мур, Чарльз, 1-й маркиз Дрохеда' with size 6.06 KB
# Saved 'Кожым' with size 0.50 KB
# Saved 'Сведберг, Жаклин' with size 0.81 KB
# Saved 'Иммануил' with size 1.27 KB
# Saved 'Уе-Докья' with size 1.50 KB
# Saved 'Волна де Бройля' with size 54.36 KB
# Saved 'Стемонитис бурый' with size 1.65 KB
# Saved 'Юшала (посёлок)' with size 3.82 KB
# Saved 'Новолуние (значения)' with size 0.67 KB
# Saved 'Сафронников, Леонид Игоревич' with size 4.60 KB
# Saved 'Скробово' with size 0.34 KB
# Saved 'Audi museum mobile' with size 1.78 KB
# Saved 'Камелик (село)' with size 3.37 KB
# Saved 'Одышка (значения)' with size 0.36 KB
# Saved 'Список умерших в 628 году' with size 1.68 KB
# Saved 'Риф, Даниэла' with size 9.59 KB
# Saved 'Радиальные спицы' with size 3.03 KB
# Saved 'Больше не пишу' with size 3.51 KB
# Saved 'Guess Who’s Coming to Criticize Dinner?' with size 2.47 KB
# Saved 'Кенто (озеро)' with size 2.34 KB
# Saved 'Экономика Российской империи' with size 96.79 KB
# Saved 'Крымская светлица' with size 16.88 KB
# Saved 'Годефруа, Иоанн Цезарь' with size 3.57 KB
# Saved 'Кочаки' with size 3.28 KB
# Saved 'Франческа Ле' with size 3.14 KB
# Saved 'Кингсеп, Александр Сергеевич' with size 4.79 KB
# Saved 'Бребьер' with size 2.25 KB
# Saved 'Мезо (рэпер)' with size 2.39 KB
# Saved 'Кампхэнгпхет' with size 1.92 KB
# Saved 'Пассажир из Франкфурта' with size 3.48 KB
# Saved 'XXI Стремительный легион' with size 3.36 KB
# Saved 'Фримпонг, Акваси' with size 3.49 KB
# Saved 'Кубок Ала-Тоо' with size 2.18 KB
# Saved 'Аустраль' with size 4.54 KB
# Saved 'Вена 1931 (шахматный турнир)' with size 0.69 KB
# Saved 'Гендерное неравенство' with size 11.93 KB
# Saved 'Базельская конвенция' with size 7.23 KB
# Saved 'Кинду' with size 1.58 KB
# Saved '2624 км (значения)' with size 1.11 KB
# Saved 'Фили (регбийный клуб)' with size 11.60 KB
# Saved 'Арасатуба (микрорегион)' with size 1.65 KB
# Saved 'Диплодок Карнеги' with size 8.39 KB
# Saved 'Эдисон (фильм)' with size 2.73 KB
# Saved 'Бёрдуелл, Дуайт Уэйн' with size 8.29 KB
# Saved 'Дьявол и десять заповедей' with size 9.28 KB
# Saved 'Лыщево' with size 0.43 KB
# Saved 'TGV' with size 80.62 KB
# Saved 'Тальники (Ростовская область)' with size 0.87 KB
# Saved 'Богатырёва, Людмила Семёновна' with size 1.75 KB
# Saved 'Леттнер (архитектура)' with size 2.86 KB
# Saved 'Спорт в Косове' with size 7.04 KB
# Saved 'Тезис об упадке Османской империи' with size 56.87 KB
# Saved 'Баранов, Евгений Александрович' with size 0.45 KB
# Saved 'Сан-Тимотео (титулярная церковь)' with size 0.83 KB
# Saved 'Занет, Фёдор Иванович' with size 6.51 KB
# Saved 'Оболенский, Сергей Сергеевич' with size 3.10 KB
# Saved 'Флаг Мичуринского сельского поселения' with size 0.29 KB
# Saved 'Манидакис, Стилианос' with size 21.70 KB
# Saved 'Грузинский язык' with size 16.68 KB
# Saved 'Treasure EP.Fin: All to Action' with size 1.27 KB
# Saved 'Пикус, Евгений Михайлович' with size 6.07 KB
# Saved 'Двойные неприятности Святого' with size 36.17 KB
# Saved 'Северо-сахарские степи и редколесья' with size 4.32 KB
# Saved 'Куиннипиаки' with size 3.54 KB
# Saved 'Коцк (гмина)' with size 0.52 KB
# Saved 'Армстронг, Райан Кира' with size 3.87 KB
# Saved 'Санта-Крус' with size 6.63 KB
# Saved 'Долгий (Фатежский район)' with size 3.57 KB
# Saved 'Бенувиль' with size 0.46 KB
# Saved 'Жабокрыт' with size 1.04 KB
# Saved 'Шевчик, Михал (писатель)' with size 3.04 KB
# Saved 'Сексуальные дисфункции' with size 0.91 KB
# Saved 'Обыкновенный дискус' with size 4.16 KB
# Saved 'Эквадорская тройнозубая акула' with size 3.62 KB
# Saved 'Mega Man V (Game Boy)' with size 3.39 KB
# Saved 'Остров (группа художников)' with size 3.30 KB
# Saved 'Заблудув (гмина)' with size 0.98 KB
# Saved 'Чоно (народ)' with size 5.92 KB
# Saved 'Берлаге' with size 0.78 KB
# Saved 'Слободские люди' with size 3.25 KB
# Saved 'Бьютт (округ)' with size 0.62 KB
# Saved 'Лосьон' with size 1.93 KB
# Saved 'Есмырза' with size 0.59 KB
# Saved 'Матуте, Ана Мария' with size 7.82 KB
# Saved 'Административное деление Онтарио' with size 11.56 KB
# Saved 'Байерс, Стив' with size 1.68 KB
# Saved 'Эпикриз' with size 12.74 KB
# Saved 'Хеберлин, Генрих' with size 3.03 KB
# Saved 'Ла-Мут' with size 2.77 KB
# Saved 'Чемпионат России по кёрлингу среди смешанных пар 2021' with size 5.33 KB
# Saved 'Цветок моря' with size 6.42 KB
# Saved 'Эпоха Плантагенетов' with size 154.48 KB
# Saved 'Седайнш' with size 0.68 KB
# Saved 'Качча (значения)' with size 0.52 KB
# Saved 'NGC 5149' with size 0.98 KB
# Saved 'Андреевичи (Житомирская область)' with size 0.77 KB
# Saved 'Погост-2' with size 4.06 KB
# Saved 'Всяких, Алексей Семёнович' with size 4.75 KB
# Saved 'Комедия давно минувших дней' with size 7.04 KB
# Saved 'Перъединичная матрица' with size 8.88 KB
# Saved '704 год до н. э.' with size 2.55 KB
# Saved 'Эскадроны смерти Железной гвардии' with size 17.55 KB
# Saved 'Батыралиев, Талантбек Абдуллаевич' with size 7.98 KB
# Saved 'PowerBrowser' with size 1.56 KB
# Saved 'Брайан, Кэтрин' with size 2.96 KB
# Saved 'Анетовская культура' with size 3.93 KB
# Saved 'Баклановская (Ростовская область)' with size 7.55 KB
# Saved 'Гнедич, Пётр Петрович' with size 11.78 KB
# Saved 'Новошахтинск' with size 18.81 KB
# Saved 'Желудково (Вологодская область)' with size 1.26 KB
# Saved 'Мусульмане за прогрессивные ценности' with size 9.90 KB
# Saved 'Федеральная служба по оборонному заказу' with size 10.93 KB
# Saved 'Памятник Серафиму Саровскому (Орёл)' with size 2.76 KB
# Saved 'Флаг сельского поселения Федоскинское' with size 5.99 KB
# Saved 'Рид, Уолтер' with size 4.09 KB
# Saved 'Лакун' with size 0.40 KB
# Saved 'Ивашутино' with size 0.32 KB
# Saved '5-я армия ВВС и ПВО' with size 2.12 KB
# Saved 'Ромеи' with size 0.59 KB
# Saved 'Зареченское сельское поселение (Архангельская область)' with size 1.25 KB
# Saved 'Крамерс, Йоханнес Хендрик' with size 14.63 KB
# Saved '«Нью-Джерси Нетс» в сезоне 2008/2009' with size 2.24 KB
# Saved 'Новосёловка (Оржицкий район)' with size 1.43 KB
# Saved 'SN 1997D' with size 1.69 KB
# Saved 'Сельское поселение «Ишагинское»' with size 1.35 KB
# Saved 'Безерра да Силва' with size 0.50 KB
# Saved 'Пасечная (Ярмолинецкая поселковая община)' with size 0.79 KB
# Saved 'Новоульяновка (Кировоградская область)' with size 0.74 KB
# Saved 'Поиск с запретами' with size 20.58 KB
# Saved 'Уварово (городской округ Домодедово, бывший Растуновский сельский округ)' with size 0.68 KB
# Saved 'Коровяк тараканий' with size 3.66 KB
# Saved 'Ла-Моттери, Кретьен-Жозеф-Грегуар-Эрнест де Ланнуа' with size 5.95 KB
# Saved 'Сэра (монастырь)' with size 3.88 KB
# Saved 'Ингода' with size 5.08 KB
# Saved 'Маяк Харст-Пойнт' with size 1.62 KB
# Saved 'Терменевский сельсовет' with size 0.98 KB
# Saved 'Тимофеева, Софья Никитична' with size 4.58 KB
# Saved 'Фумагалли, Полибио' with size 2.30 KB
# Saved 'Волкуша (приток Ухтохмы)' with size 0.51 KB
# Saved 'Сушич' with size 0.54 KB
# Saved 'Орланы' with size 2.54 KB
# Saved 'Стереотип (полиграфия)' with size 2.50 KB
# Saved 'Ким Наён' with size 0.58 KB
# Saved 'Гули' with size 2.15 KB
# Saved 'Азизов, Алишер' with size 2.92 KB
# Saved 'Therates concinnus' with size 2.09 KB
# Saved 'Плессас, Мимис' with size 3.17 KB
# Saved 'Кошачий геккон' with size 2.18 KB
# Saved 'Лекторий Dостоевский' with size 5.32 KB
# Saved 'Жёлто-зелёный доминиканский ара' with size 1.56 KB
# Saved 'Душевные смуты воспитанника Тёрлеса' with size 8.06 KB
# Saved 'Знаменское-Губайлово' with size 5.80 KB
# Saved 'Немков, Валентин Сергеевич' with size 32.23 KB
# Saved 'Эргич, Иван' with size 8.10 KB
# Saved 'Опасная земля (фильм)' with size 3.98 KB
# Saved 'Показатель преломления' with size 195.96 KB
# Saved 'Рори Уильямс' with size 6.24 KB
# Saved 'Памятник Александру Суворову' with size 1.47 KB
# Saved 'Хлопкув' with size 0.48 KB
# Saved 'Блэк, Сэмюэл Дункан' with size 10.12 KB
# Saved 'Буонметхуот (аэропорт)' with size 1.33 KB
# Saved 'Науэльпан, Ариэль' with size 4.39 KB
# Saved 'Список национальных автогоночных цветов' with size 0.89 KB
# Saved 'Тетеринг' with size 3.86 KB
# Saved 'Стонятино (Ярославская область)' with size 2.57 KB
# Saved 'Ильин, Марк Александрович' with size 16.02 KB
# Saved 'Матцинген' with size 0.47 KB
# Saved 'Бузиашвили, Юрий Иосифович' with size 5.99 KB
# Saved 'Олай' with size 0.10 KB
# Saved 'Святая Екатерина (линейный корабль, 1721)' with size 5.09 KB
# Saved 'Доул, Элизабет' with size 1.92 KB
# Saved 'CoRoT-2 b' with size 3.29 KB
# Saved 'Блуме, Фридрих' with size 3.15 KB
# Saved 'Росси, Марко (футболист, 1987)' with size 1.10 KB
# Saved 'Максштадт' with size 1.54 KB
# Saved 'Фьёртофт, Ян Оге' with size 2.62 KB
# Saved 'Моноссон' with size 0.13 KB
# Saved 'Сады Верхней Барракки' with size 2.72 KB
# Saved 'Сартык' with size 2.34 KB
# Saved 'Маш (приток Сарса)' with size 1.09 KB
# Saved 'АЭС Уотерфорд' with size 2.79 KB
# Saved 'Находчивая Гретель' with size 7.50 KB
# Saved 'Ишино' with size 0.43 KB
# Saved 'Докучаев, Михаил Павлович' with size 15.38 KB
# Saved 'Дамик-илишу II' with size 1.09 KB
# Saved 'Филодем из Гадары' with size 5.94 KB
# Saved 'И вновь продолжается бой' with size 3.59 KB
# Saved 'Правительство Еханурова' with size 15.97 KB
# Saved 'Гринхаус, Кэрол' with size 2.20 KB
# Saved 'Михеева, Тамара Михайловна' with size 11.93 KB
# Saved 'Премьер-министр Республики Абхазия' with size 2.44 KB
# Saved 'Чемпионат Украины по футболу 2014/2015 (результаты матчей)' with size 0.84 KB
# Saved 'Rostelecom Cup 2013' with size 1.00 KB
# Saved 'Camel (группа)' with size 46.53 KB
# Saved 'Новиков, Виктор Павлович' with size 3.69 KB
# Saved 'Вершинский, Анатолий Николаевич' with size 10.72 KB
# Saved 'Алкснис, Арнольд Фрицевич' with size 3.27 KB
# Saved 'Фано' with size 1.30 KB
# Saved 'Галатин' with size 0.86 KB
# Saved 'Нартова, Нина Кузьминична' with size 2.59 KB
# Saved 'Чкония, Мерием Хасановна' with size 2.39 KB
# Saved 'Стефано, Джозеф' with size 8.08 KB
# Saved 'Биоинформатика' with size 37.93 KB
# Saved 'Липово (Добрянский район)' with size 3.91 KB
# Saved 'Четыре дня Дюнкерка 2015' with size 1.31 KB
# Saved 'Полупростое число' with size 1.93 KB
# Saved 'Горгиладзе, Хаджер Мемедовна' with size 2.41 KB
# Saved 'Open GDF Suez 2011' with size 1.86 KB
# Saved 'Новые философы' with size 2.87 KB
# Saved 'Аск, Беатрис' with size 4.84 KB
# Saved 'Кайе дю синема' with size 7.20 KB
# Saved 'Житомирский, Константин Григорьевич' with size 8.92 KB
# Saved 'Флавий Иоанн Винкомал' with size 1.32 KB
# Saved 'Суровые километры' with size 3.22 KB
# Saved 'Харрингтон' with size 3.30 KB
# Saved 'Федеральный прокурор США' with size 9.35 KB
# Saved 'Гулар, Франсуа' with size 12.58 KB
# Saved 'Сория, Элеасар' with size 2.43 KB
# Saved 'Костюков, Владимир Николаевич (конструктор)' with size 3.56 KB
# Saved 'Салимова, Шовкет Шахбаз кызы' with size 4.39 KB
# Saved 'Каучуковое дерево' with size 1.44 KB
# Saved 'Гиндорф' with size 0.42 KB
# Saved 'Андрюхин, Фёдор Александрович' with size 1.75 KB
# Saved 'Инжуватова, Галина Дмитриевна' with size 2.14 KB
# Saved 'Языки Камеруна' with size 4.41 KB
# Saved 'Запасной дворец Бориса Годунова' with size 4.31 KB
# Saved 'Воробьёв, Владимир Анатольевич' with size 5.45 KB
# Saved 'Спатодея' with size 2.50 KB
# Saved 'Метрополитен Боготы' with size 2.88 KB
# Saved 'Apterostigma dentigerum' with size 2.73 KB
# Saved 'Walking in the Rain' with size 1.48 KB
# Saved 'Ферендат (сатрап Египта IV века до н. э.)' with size 1.78 KB
# Saved 'Четыре Угла (США)' with size 1.63 KB
# Saved 'Панюшкин, Юрий Михайлович' with size 7.49 KB
# Saved 'Чепелеуць' with size 0.99 KB
# Saved 'Сысоевский сельсовет (Московская область)' with size 2.30 KB
# Saved 'Чьеу Ай-выонг' with size 3.92 KB
# Saved 'Акмурзаев, Тоза' with size 1.33 KB
# Saved 'Коллективы солидарности' with size 9.06 KB
# Saved 'Одинокому везде пустыня' with size 0.88 KB
# Saved 'Теорема о запрете клонирования' with size 11.06 KB
# Saved 'Список награждённых орденом Академических пальм' with size 11.09 KB
# Saved 'Чемпионат Туркменистана по футболу 2011' with size 1.15 KB
# Saved 'Больница (фильм)' with size 6.00 KB
# Saved 'Эвелин Брент' with size 2.83 KB
# Saved 'Доминиканцы в Белоруссии' with size 32.69 KB
# Saved 'Розенталь, Татьяна Конрадовна' with size 5.04 KB
# Saved 'Разин, Евгений Андреевич' with size 9.74 KB
# Saved 'Яблонский, Дариуш' with size 0.25 KB
# Saved 'Гран-при По' with size 2.96 KB
# Saved 'Росскопф, Джои' with size 0.85 KB
# Saved 'Стамбульский военно-морской музей' with size 1.52 KB
# Saved 'Соты' with size 0.07 KB
# Saved 'Коктал (Байзакский район)' with size 1.58 KB
# Saved 'Мария Магдалина (картина Сэндиса)' with size 2.23 KB
# Saved 'Ком (посёлок)' with size 0.45 KB
# Saved 'Smash the House' with size 1.07 KB
# Saved 'Кавендиш, Фредерик (фельдмаршал)' with size 4.92 KB
# Saved 'Проповедник (телесериал)' with size 13.24 KB
# Saved 'Кунистино Малое' with size 1.21 KB
# Saved 'Премия имени А. А. Баева' with size 3.55 KB
# Saved 'Рок (Кальвадос)' with size 1.36 KB
# Saved 'Ядозубы' with size 25.59 KB
# Saved 'Виноделие в России' with size 22.53 KB
# Saved 'NGC 6335' with size 0.73 KB
# Saved 'Кристинн Йонссон' with size 3.22 KB
# Saved 'Тропарёвский парк' with size 9.12 KB
# Saved 'ДОТ № 409 (КиУР)' with size 5.55 KB
# Saved 'Большой Руфабго' with size 1.95 KB
# Saved 'Центральный (кинотеатр, Минск)' with size 2.39 KB
# Saved 'Правительство национального единства' with size 3.85 KB
# Saved 'Кармен и Лола' with size 3.90 KB
# Saved 'Милютин, Дмитрий Алексеевич' with size 48.29 KB
# Saved 'Сикора (остров)' with size 5.04 KB
# Saved 'Петруниас, Элефтериос' with size 2.45 KB
# Saved 'Билу' with size 0.52 KB
# Saved 'Карасёва, Татьяна Александровна' with size 1.39 KB
# Saved 'Gioiella' with size 1.70 KB
# Saved 'Огняк' with size 1.96 KB
# Saved 'CD47' with size 8.57 KB
# Saved 'Вагин, Сергей Тимофеевич' with size 10.79 KB
# Saved 'О’Брайен, Марк' with size 2.65 KB
# Saved 'Холоповицы (Гатчинский район)' with size 6.76 KB
# Saved 'Датас' with size 1.23 KB
# Saved 'Shuka' with size 0.91 KB
# Saved 'Рыхотка (Тульская область)' with size 2.58 KB
# Saved 'Санный спорт на зимних Олимпийских играх 2018 — эстафета' with size 1.79 KB
# Saved 'Добрая (Черкасская область)' with size 0.63 KB
# Saved 'Биддл, Адриан' with size 3.38 KB
# Saved 'Хохфельд, Джейн' with size 2.80 KB
# Saved 'The Marshall Suite' with size 4.83 KB
# Saved 'Медаль «В память русско-турецкой войны 1877—1878»' with size 8.46 KB
# Saved 'Ленсинас, Карлос Вашингтон' with size 6.95 KB
# Saved 'Сириус ФМ-6' with size 7.18 KB
# Saved 'Зиновьево (Ростовский район)' with size 2.44 KB
# Saved 'Fiat 128' with size 3.50 KB
# Saved 'Rhinotia haemoptera' with size 0.55 KB
# Saved 'Свинецтетранатрий' with size 1.58 KB
# Saved 'Чемпионат России по боксу 2011' with size 0.37 KB
# Saved 'Шемоне-Эсре' with size 12.58 KB
# Saved 'Акимов, Фёдор' with size 0.42 KB
# Saved 'Кривошеин' with size 1.74 KB
# Saved 'Suno AI' with size 4.26 KB
# Saved 'Валье-де-Матаморос' with size 0.68 KB
# Saved 'Стефановский, Пётр Михайлович' with size 11.30 KB
# Saved 'Син Пундан' with size 3.91 KB
# Saved 'Общество миссионеров святого Павла' with size 4.47 KB
# Saved 'Шамбоншар' with size 1.33 KB
# Saved 'Чемпионат Белоруссии по шашечной композиции 1982' with size 5.03 KB
# Saved 'Хахилево (Курская область)' with size 2.49 KB
# Saved 'Светлая Речка (Екатеринбург)' with size 2.60 KB
# Saved 'Лыжный переулок' with size 0.50 KB
# Saved 'Волков, Николай Львович' with size 17.52 KB
# Saved 'Рельсоочистительная машина' with size 4.38 KB
# Saved 'Сере (ном)' with size 2.61 KB
# Saved 'Балыкса (Алтайский край)' with size 0.92 KB
# Saved 'Три Озера' with size 11.29 KB
# Saved 'Браункер, Уильям, 2-й виконт Браункер' with size 21.02 KB
# Saved 'Ульяновка (Атяшевский район)' with size 0.75 KB
# Saved 'Список высших учебных заведений Костромской области' with size 0.94 KB
# Saved 'HMS Amethyst' with size 1.62 KB
# Saved 'Тишина, Наталья Борисовна' with size 4.34 KB
# Saved 'Москос, Элиас' with size 1.92 KB
# Saved 'Бредихино (Добринский район)' with size 0.64 KB
# Saved 'Параллель (траншея)' with size 6.51 KB
# Saved 'Жуковский сельсовет' with size 2.21 KB
# Saved 'Слиач' with size 1.11 KB
# Saved 'Армяне в Северной Македонии' with size 1.91 KB
# Saved 'Слипак, Василий Ярославович' with size 39.88 KB
# Saved 'Армия моджахедов (Ирак)' with size 2.72 KB
# Saved 'Рыбников, Александр Ильич' with size 4.66 KB
# Saved 'Сеймур, Элизабет' with size 1.41 KB
# Saved 'Саук-Дере' with size 5.43 KB
# Saved 'Чемпионат Японии по кёрлингу среди женщин 2017' with size 2.69 KB
# Saved 'Муруй' with size 2.08 KB
# Saved 'Конституционная партия (Перу)' with size 1.82 KB
# Saved 'Перебейнос, Валентина Исидоровна' with size 4.35 KB
# Saved 'Монастырь Святого Геворга (Чанакдюзю)' with size 5.99 KB
# Saved '8-й Латышский стрелковый Вольмарский полк' with size 7.55 KB
# Saved 'Баризон' with size 0.47 KB
# Saved 'Открытый чемпионат Майами по теннису 2018' with size 8.85 KB
# Saved 'Административно-территориальное деление Башкортостана' with size 17.57 KB
# Saved 'Император Дайго' with size 1.58 KB
# Saved 'Косянчук, Фёдор Яковлевич' with size 3.44 KB
# Saved 'Хёэнланд' with size 0.50 KB
# Saved 'SOHO (Шарм-эш-Шейх)' with size 3.18 KB
# Saved 'Зелигсон, Адольф Ноевич' with size 8.99 KB
# Saved 'Стрельское' with size 1.71 KB
# Saved 'Болоньское сельское поселение' with size 0.45 KB
# Saved 'Тимотесубани (храм)' with size 3.35 KB
# Saved 'Жихарев, Степан Сергеевич' with size 3.67 KB
# Saved 'Кэмпбелл, Коул' with size 1.93 KB
# Saved 'Sudeki' with size 9.13 KB
# Saved 'Вертемате-кон-Миноприо' with size 0.82 KB
# Saved 'Феррари, Джованни' with size 3.89 KB
# Saved 'Ashampoo Burning Studio' with size 2.22 KB
# Saved 'Биренбойм, Яков Абрамович' with size 2.59 KB
# Saved 'Премия «Сатурн» лучшему телеактёру' with size 3.14 KB
# Saved 'Угорский, Анатолий Зальманович' with size 8.51 KB
# Saved 'Чемпионат Польши по шахматам 1961' with size 1.06 KB
# Saved 'NGC 1511' with size 1.73 KB
# Saved 'Пьяная курица' with size 3.12 KB
# Saved 'Полозайка' with size 0.99 KB
# Saved 'Военный крест (Люксембург)' with size 2.99 KB
# Saved 'Фридлендер, Юлий' with size 2.70 KB
# Saved 'Шарур' with size 4.97 KB
# Saved 'Сила каббалы (книга)' with size 2.83 KB
# Saved 'Владимировское' with size 0.90 KB
# Saved 'Дике (значения)' with size 0.44 KB
# Saved 'Perl Shell' with size 1.30 KB
# Saved 'Кайалес, Спирос' with size 11.19 KB
# Saved 'Сибирская старина' with size 1.75 KB
# Saved 'Коррупция в Кыргызстане' with size 46.21 KB
# Saved 'Когуашвили, Леван' with size 6.09 KB
# Saved 'Братоножичи' with size 15.52 KB
# Saved 'Нанино, Джованни Бернардино' with size 6.88 KB
# Saved 'Хаддингтон (гора)' with size 0.89 KB
# Saved 'Chloe Dancer/Crown of Thorns' with size 1.76 KB
# Saved 'Кремиковский металлургический комбинат' with size 7.56 KB
# Saved 'Мерод-Вестерло, Жан-Филипп-Эжен де' with size 19.35 KB
# Saved 'Call of the Night' with size 13.31 KB
# Saved 'Swedish House Mafia' with size 10.04 KB
# Saved 'Хорошев, Пётр Иванович' with size 12.08 KB
# Saved 'Иордания' with size 44.96 KB
# Saved 'Валь-де-Пре' with size 2.25 KB
# Saved 'Инсургенты' with size 3.36 KB
# Saved 'My Generation' with size 9.81 KB
# Saved 'Ганс Мале' with size 12.94 KB
# Saved 'Эдриоастероидеи' with size 5.92 KB
# Saved 'Истории Райли' with size 14.34 KB
# Saved 'Белобрюхий рябок' with size 2.53 KB
# Saved '52-й армейский корпус (вермахт)' with size 2.32 KB
# Saved 'Атака Pass-the-hash' with size 15.92 KB
# Saved 'Loco (песня Тимати)' with size 3.22 KB
# Saved 'Оксид кобальта(II,III)' with size 10.03 KB
# Saved 'Рейген, Джексон' with size 3.40 KB
# Saved 'Матч СССР — США по боксу 1975' with size 2.74 KB
# Saved 'Кира (Япония)' with size 1.64 KB
# Saved 'Джонс, Томас (футболист, 1964)' with size 2.09 KB
# Saved 'Петухов Лог (Алтайский край)' with size 2.23 KB
# Saved 'Дельтаплан' with size 14.12 KB
# Saved 'Бутырская улица (Москва)' with size 11.53 KB
# Saved 'Лётная улица (Чернигов)' with size 5.29 KB
# Saved 'Berkeleyia hadala' with size 2.07 KB
# Saved 'Рассел, Уильям, 1-й барон Рассел из Торнхау' with size 5.50 KB
# Saved 'Харасавэйское газоконденсатное месторождение' with size 2.60 KB
# Saved 'Апостолово (локомотивное депо)' with size 4.50 KB
# Saved 'Лист, Франц фон' with size 8.40 KB
# Saved 'Культурный фонд Норвегии' with size 2.08 KB
# Saved 'Джупитер-Айленд (Флорида)' with size 4.44 KB
# Saved 'MTA2' with size 2.41 KB
# Saved 'Циолек, Влодзимеж' with size 1.48 KB
# Saved 'Govinda' with size 3.98 KB
# Saved 'Атеев, Алексей Григорьевич' with size 15.23 KB
# Saved 'Дарвин (тауншип, Миннесота)' with size 2.87 KB
# Saved 'Сад собора Святого Юра' with size 1.10 KB
# Saved 'Трояновский, Олег Александрович' with size 8.79 KB
# Saved 'Вертолётная площадка (Самара)' with size 4.73 KB
# Saved 'Ямагути (город)' with size 3.22 KB
# Saved 'Рамбледетампс' with size 1.98 KB
# Saved 'Брэдли, Том' with size 2.35 KB
# Saved 'Голованов, Василий Ярославович' with size 4.94 KB
# Saved 'Кальяндриш' with size 0.92 KB
# Saved 'Yahoo! 360°' with size 7.68 KB
# Saved 'Варнсдорф (футбольный клуб)' with size 2.05 KB
# Saved 'Нидерланды на «Евровидении-1964»' with size 1.83 KB
# Saved 'Маян, Маржори' with size 2.38 KB
# Saved 'Музей Людвига (Будапешт)' with size 2.37 KB
# Saved 'Анновка (Калужская область)' with size 1.83 KB
# Saved 'Улс' with size 5.41 KB
# Saved 'Вепшенец' with size 0.25 KB
# Saved 'Вий (группа)' with size 7.31 KB
# Saved 'Сан-Хасинто (Колумбия)' with size 3.00 KB
# Saved 'Жоффруа, Клод Франсуа' with size 2.23 KB
# Saved 'Маргиева, Марина Сослановна' with size 1.68 KB
# Saved 'Обнажённые души' with size 2.88 KB
# Saved 'Чемпионат Австрии по кёрлингу среди смешанных команд' with size 2.04 KB
# Saved 'Екатериноградский уезд' with size 3.51 KB
# Saved 'Аламеда-и-Бреа, Сирило де' with size 0.77 KB
# Saved 'Хэккетт, Дэниел' with size 2.52 KB
# Saved 'Гиниятуллин, Марат Гиндуллинович' with size 5.02 KB
# Saved 'Центристская концепция' with size 25.31 KB
# Saved 'Рижский технический университет' with size 20.02 KB
# Saved '87-й полицейский участок (значения)' with size 0.46 KB
# Saved 'Пангенезис' with size 7.24 KB
# Saved 'Благовещенский собор (Каунас)' with size 2.13 KB
# Saved 'Лев III Исавр' with size 25.73 KB
# Saved 'Решедько, Галина Константиновна' with size 3.06 KB
# Saved 'Острасьевы яры' with size 2.29 KB
# Saved '21-я пехотная дивизия (Российская империя)' with size 17.79 KB
# Saved 'Сюрвиль (Кальвадос)' with size 1.37 KB
# Saved 'Сергеев, Борис Иванович' with size 6.20 KB
# Saved 'Престес, Анита Леокадия' with size 2.31 KB
# Saved 'Варпаярви' with size 0.33 KB
# Saved 'Одическая строфа' with size 4.44 KB
# Saved 'Мочалов, Вячеслав Иванович' with size 4.80 KB
# Saved 'Котовский сельский совет (Магдалиновский район)' with size 0.49 KB
# Saved 'Бондарь, Иван Калистратович' with size 3.56 KB
# Saved 'V Большого Пса' with size 0.74 KB
# Saved 'Хулбук (значения)' with size 0.41 KB
# Saved 'Сапогов, Александр' with size 0.30 KB
# Saved 'Герб Пярнумаа' with size 1.78 KB
# Saved 'Скрябинки' with size 3.65 KB
# Saved 'Лаха-Варанды' with size 1.70 KB
# Saved 'Новая Гребля (Винницкая область)' with size 2.78 KB
# Saved 'Можейко, Владимир Михайлович' with size 4.46 KB
# Saved 'Гуачалла, Фернандо Элой' with size 2.59 KB
# Saved 'Путь' with size 3.10 KB
# Saved 'Европа — Действие' with size 24.65 KB
# Saved 'Кисель, Николай' with size 4.98 KB
# Saved 'Молчанов, Григорий Дмитриевич' with size 2.28 KB
# Saved 'Бре-Сен-Кристоф' with size 1.38 KB
# Saved 'Андрейчин, Георгий Илькович' with size 9.86 KB
# Saved 'Бандера (округ)' with size 0.73 KB
# Saved 'Перевозново' with size 2.44 KB
# Saved 'Пён Чхон Са' with size 6.47 KB
# Saved 'Acalolepta nivosa' with size 0.30 KB
# Saved 'Торндиррап' with size 6.69 KB
# Saved 'Тарас Бульба' with size 46.33 KB
# Saved 'Васильева, Юлия Олеговна' with size 1.37 KB
# Saved 'Межадор (сельское поселение)' with size 1.53 KB
# Saved 'Бакай, Анна Александровна' with size 2.55 KB
# Saved 'Флаг Приволжского района (Самарская область)' with size 6.74 KB
# Saved 'Премия «Энни» за лучшую раскадровку в анимационном полнометражном фильме' with size 1.15 KB
# Saved 'Далматов, Дмитрий Яковлевич' with size 9.62 KB
# Saved 'Ново-Ивановское (Ярославская область)' with size 2.69 KB
# Saved 'Ямаш (Альметьевский район)' with size 1.20 KB
# Saved 'Синенькие (Петровский район)' with size 0.60 KB
# Saved 'Михайловка (Баштанский район)' with size 0.73 KB
# Saved 'Магомедов, Абдулла Омарович' with size 1.12 KB
# Saved 'Камень забвения горя' with size 0.58 KB
# Saved 'V1117 Геркулеса' with size 1.01 KB
# Saved 'Дьёр' with size 9.61 KB
# Saved 'Монток (значения)' with size 0.49 KB
# Saved 'Кулиш, Савва Яковлевич' with size 2.82 KB
# Saved 'Татарка (Курская область)' with size 2.37 KB
# Saved 'Список эпизодов телесериала «Звёздный путь: Оригинальный сериал»' with size 14.37 KB
# Saved 'Rhododendron alutaceum' with size 2.23 KB
# Saved 'Магадов, Артур Маликастарович' with size 2.32 KB
# Saved 'Лаг (компьютерный сленг)' with size 18.38 KB
# Saved 'Яннакис, Георгиос' with size 19.60 KB
# Saved 'Железнодорожное машиностроение России' with size 19.47 KB
# Saved 'Чернявский, Василий Ефимович' with size 5.14 KB
# Saved 'Аминдеон' with size 3.12 KB
# Saved 'Мокруха розовая' with size 3.36 KB
# Saved 'Харпезавр Модильяни' with size 1.08 KB
# Saved 'Верхнечесноченский сельсовет' with size 0.98 KB
# Saved 'Равна, Оле' with size 3.70 KB
# Saved 'Галкино (Павлодарская область)' with size 0.75 KB
# Saved 'Сапаров, Малик Мухамеджанович' with size 3.82 KB
# Saved 'Круглый дом' with size 3.37 KB
# Saved 'Официальный рейтинг снукеристов на сезон 1976/1977' with size 1.05 KB
# Saved 'Список глав государств в 1282 году' with size 22.97 KB
# Saved 'Клутье, Гэри' with size 0.81 KB
# Saved 'Стамбульский аэропорт имени Ататюрка' with size 5.63 KB
# Saved 'Глушка (Габровская область)' with size 0.68 KB
# Saved 'Тищенко, Матвей Матвеевич' with size 5.17 KB
# Saved 'Билетникофф, Фред' with size 16.17 KB
# Saved 'Моргун, Алексей Григорьевич' with size 4.55 KB
# Saved 'Эволюционный анахронизм' with size 9.84 KB
# Saved 'Теория сатисфакции' with size 7.71 KB
# Saved 'Audi RS3' with size 4.07 KB
# Saved 'Сильвестр (Сембратович)' with size 2.78 KB
# Saved 'Nemotarsus' with size 0.88 KB
# Saved 'Подхоз (Бурабайский район)' with size 2.11 KB
# Saved 'Сафронова, Ольга' with size 0.26 KB
# Saved 'Штаб-квартира Европейского центрального банка' with size 6.66 KB
# Saved 'Fromis 9' with size 9.23 KB
# Saved 'Энигэреску, Октав' with size 3.29 KB
# Saved 'Коровин, Александр Михайлович' with size 0.30 KB
# Saved 'Демьянка (Вологодская область)' with size 0.98 KB
# Saved 'Козевская' with size 1.03 KB
# Saved 'Парламентские выборы в Сальвадоре (2003)' with size 2.49 KB
# Saved 'Алан (порода собак)' with size 2.15 KB
# Saved 'Сенмар' with size 1.88 KB
# Saved 'Ельяшкевич, Александр Сергеевич' with size 6.84 KB
# Saved 'Suzuki Ertiga' with size 2.19 KB
# Saved 'Игнатово (Орехово-Зуевский район)' with size 1.69 KB
# Saved 'Фолькард' with size 2.40 KB
# Saved 'Реакция Молиша' with size 2.96 KB
# Saved 'Дикомо' with size 0.79 KB
# Saved 'Малая Миссури' with size 1.36 KB
# Saved 'Хенг Сомнанг Нгор' with size 9.54 KB
# Saved 'Араньяш' with size 0.67 KB
# Saved 'Политический кризис на Украине' with size 0.51 KB
# Saved 'Сухоручко, Даниил Анатольевич' with size 2.85 KB
# Saved 'Белур' with size 1.53 KB
# Saved 'Туарма (село)' with size 4.96 KB
# Saved 'Ходиев, Собир' with size 3.92 KB
# Saved 'Гриб-зонтик краснеющий' with size 9.04 KB
# Saved 'Кубок Лаги' with size 1.37 KB
# Saved 'Караоткель' with size 0.43 KB
# Saved 'Модальность (лингвистика)' with size 10.38 KB
# Saved 'Роже Бернар II де Фуа' with size 11.48 KB
# Saved 'Иж-Борискино' with size 2.21 KB
# Saved 'Луций Постумий' with size 0.51 KB
# Saved 'Малые пастушки' with size 1.22 KB
# Saved 'Шихов' with size 1.46 KB
# Saved 'Египетский фунт' with size 3.38 KB
# Saved 'Подгорный Байлар' with size 4.46 KB
# Saved 'Боссе-Гриффитс, Кете' with size 7.29 KB
# Saved 'RWD-11' with size 3.00 KB
# Saved 'Список чрезвычайных и полномочных послов России' with size 2.03 KB
# Saved 'Абу Хайян аль-Гарнати' with size 2.53 KB
# Saved 'Кребс, Пейтон' with size 3.94 KB
# Saved 'Роспонд, Станислав (лингвист)' with size 7.21 KB
# Saved 'Рога (деревня)' with size 1.98 KB
# Saved 'Келли, Брайан (шахматист)' with size 0.99 KB
# Saved 'Асаф Джах VII' with size 10.56 KB
# Saved 'Людовик II (король Италии)' with size 7.59 KB
# Saved 'Авлон, Джон' with size 14.25 KB
# Saved 'Ватагино (Тверская область)' with size 2.31 KB
# Saved 'Хальфдан (король Дублина)' with size 10.23 KB
# Saved 'Ла-Капель-Бонанс' with size 1.96 KB
# Saved 'Проспект Айвазовского' with size 6.43 KB
# Saved 'Павлова, Маргарита Николаевна' with size 6.31 KB
# Saved 'Вертипрахов' with size 0.45 KB
# Saved 'Лядов, Александр Николаевич' with size 3.97 KB
# Saved 'Троны России' with size 5.42 KB
# Saved 'Рантеры' with size 11.49 KB
# Saved 'Исаченко, Татьяна Иосифовна' with size 38.76 KB
# Saved 'Аризона Даймондбэкс в сезоне 2005' with size 0.93 KB
# Saved 'Бергвалль, Тео' with size 2.50 KB
# Saved 'Афонин, Пётр Константинович' with size 2.80 KB
# Saved 'Дмитриев, Юрий Юрьевич' with size 6.64 KB
# Saved 'Трус, Виталий Анатольевич' with size 1.48 KB
# Saved 'Андрухович, София Юрьевна' with size 1.86 KB
# Saved 'Cold and Bouncy' with size 2.80 KB
# Saved 'Примитивная идеализация' with size 5.81 KB
# Saved 'Май 2022 года' with size 28.41 KB
# Saved 'Nine Lives (альбом Aerosmith)' with size 2.70 KB
# Saved 'Мокрянские Хутора' with size 0.95 KB
# Saved 'Домклик' with size 10.12 KB
# Saved 'Уоско (округ)' with size 3.74 KB
# Saved 'Орда, Михаил Сергеевич' with size 6.24 KB
# Saved 'Годли, Александр' with size 6.32 KB
# Saved 'Московский врачебный журнал' with size 2.18 KB
# Saved 'Шёнфельд (Саксония)' with size 1.81 KB
# Saved 'Фролов, Валерий Владимирович' with size 1.78 KB
# Saved 'Желтощёкий хохлатый гиббон' with size 3.75 KB
# Saved 'Суперфинал чемпионата России по шахматам 2019' with size 4.58 KB
# Saved 'Понимание' with size 15.20 KB
# Saved 'Хаджеты, Таймураз Григорьевич' with size 3.51 KB
# Saved 'Братья Карамазовы (фильм, 1958)' with size 2.64 KB
# Saved 'Загорское (Башкортостан)' with size 1.11 KB
# Saved 'Life Goes On (песня Тупака Шакура)' with size 1.31 KB
# Saved 'Мацуока (княжество)' with size 4.28 KB
# Saved 'Синьхуа (Лоуди)' with size 2.83 KB
# Saved 'Лун Юнь' with size 5.41 KB
# Saved 'Кеджиньский, Стефан' with size 2.19 KB
# Saved 'Уаджет' with size 5.84 KB
# Saved 'Силы специальных операций Российской Федерации' with size 20.43 KB
# Saved 'Камысты (Костанайская область)' with size 1.73 KB
# Saved 'Осечно (Пеновский район)' with size 0.98 KB
# Saved 'Митанский район' with size 1.90 KB
# Saved 'Молдаван, Николай' with size 2.04 KB
# Saved 'Андреевка (Прелестненское сельское поселение)' with size 4.01 KB
# Saved 'Конье, Гвендолин' with size 3.92 KB
# Saved 'Церковь Святого Андрея (Клепаров)' with size 1.82 KB
# Saved 'Жабер' with size 2.66 KB
# Saved 'Нельсон, Дон' with size 5.58 KB
# Saved 'Кубарев, Вячеслав' with size 0.59 KB
# Saved '304 год до н. э.' with size 3.92 KB
# Saved 'Алфимцева, Нина Никаноровна' with size 5.57 KB
# Saved 'Кобзевское водохранилище' with size 3.23 KB
# Saved 'Заяц, Леонард Иосифович' with size 3.38 KB
# Saved 'Очень новогоднее кино, или Ночь в музее' with size 4.68 KB
# Saved 'Магнитский' with size 0.42 KB
# Saved 'Трамвайная улица' with size 4.05 KB
# Saved 'Ранковце' with size 0.33 KB
# Saved 'Мокроусов, Виталий Петрович' with size 4.33 KB
# ...
# Saved 'Туарма' with size 0.32 KB
# Saved 'Гутьерре Бермудес' with size 6.88 KB
# Saved 'Mosaic.wav' with size 2.60 KB
# Saved 'Джаркешев, Зангар Асанханович' with size 3.70 KB
# Saved 'K2-58' with size 1.42 KB
# Saved 'Саннвика' with size 1.74 KB
# Saved 'Принцип причинности' with size 11.04 KB
# Saved 'Бычков, Сергей Анатольевич (легкоатлет)' with size 6.81 KB
# Saved 'Соболевский, Зигмунд' with size 8.46 KB
# Saved 'Теймер, Мартин Рохус' with size 4.05 KB
# Saved 'Моя улица (фильм)' with size 2.61 KB
# Saved 'Коксала' with size 0.27 KB
# Saved 'Розыева, Огулхан' with size 1.74 KB
# Saved 'Самос' with size 36.86 KB
# Saved 'Новозаборовский' with size 0.54 KB
# Saved 'Аксентьево (Никольский район)' with size 1.21 KB
# Saved 'Зоологический Сад (разъезд)' with size 1.24 KB
# Saved 'Касрауи, Хамди' with size 2.27 KB
# Saved 'Гавань (Забайкальский край)' with size 2.34 KB
# Saved 'Змееед' with size 0.48 KB
# Saved 'Славянский полк' with size 0.72 KB
# Saved 'Вильяфанье, Анхель де' with size 5.37 KB
# Saved 'Шультен' with size 0.53 KB
# Saved 'Плавание (значения)' with size 1.45 KB
# Saved 'Костёл Марии Снежной (Львов)' with size 1.79 KB
# Saved 'Панчо Барнс (фильм)' with size 2.11 KB
# Saved 'Дандас, Джеймс Уитли Динс' with size 1.95 KB
# Saved 'Коршалькикэ (приток Сукылтэчора)' with size 0.83 KB
# Saved 'Этьенн, Шарль-Гийом' with size 2.68 KB
# Saved 'Даймонд, Луис Клайн' with size 6.65 KB
# Saved 'Еркин (Саркандский район)' with size 0.57 KB
# Saved 'Аргис' with size 0.35 KB
# Saved 'Грудзёндзский повет' with size 1.05 KB
# Saved 'Джесси (телесериал)' with size 14.60 KB
# Saved 'Фиордализо, Марина' with size 6.99 KB
# Saved 'Ламберг, Франц Филипп' with size 1.82 KB
# Saved 'Конников, Самуил Гиршевич' with size 4.00 KB
# Saved 'Химы (Могилёвская область)' with size 2.92 KB
# Saved 'Маркин, Александр Андреевич' with size 2.98 KB
# Saved 'Смит, Марк' with size 0.80 KB
# Saved 'Варе, Луи-При' with size 5.88 KB
# Saved 'Джалу (город)' with size 0.90 KB
# Saved 'Скиннер, Каллум' with size 3.47 KB
# Saved 'Савино (озеро, Карелия)' with size 1.30 KB
# Saved 'Саар, Найма Юхановна' with size 1.29 KB
# Saved 'Мохов, Алексей Александрович' with size 2.70 KB
# Saved 'Ханата' with size 4.82 KB
# Saved 'Бородинский хлеб' with size 3.20 KB
# Saved 'Бофо, Полидор' with size 1.65 KB
# Saved 'Даниленко, Сергей Александрович (биатлонист)' with size 3.66 KB
# Saved 'Понт-Одеме (кантон)' with size 3.90 KB
# Saved 'Собор Святого Фелима (Килмор)' with size 3.23 KB
# Saved 'Ірій' with size 4.92 KB
# Saved 'Пайва, Ренато' with size 3.24 KB
# Saved 'Лос-Анхелес (Чили)' with size 2.58 KB
# Saved 'WinBoost' with size 2.14 KB
# Saved 'Кожевников, Николай Григорьевич' with size 11.76 KB
# Saved 'Улужай (посёлок)' with size 1.18 KB
# Saved 'Струя (Смоленская область)' with size 0.95 KB
# Saved 'Канзас-Сити (Миссури)' with size 12.37 KB
# Saved 'Альбертарио, Агустина' with size 2.80 KB
# Saved 'Филатов, Михаил Иванович' with size 3.47 KB
# Saved 'Бархэм, Ричард' with size 3.74 KB
# Saved 'Сентинум' with size 4.52 KB
# Saved 'Чемпионат мира по футболу 1978. Группа 1' with size 5.65 KB
# Saved 'Гудковский, Владимир Александрович' with size 5.86 KB
# Saved 'Фастат' with size 2.40 KB
# Saved 'Мин Ся' with size 3.22 KB
# Saved 'Юду' with size 5.13 KB
# Saved 'Малевичская Рудня' with size 2.73 KB
# Saved 'Березин, Николай Сергеевич' with size 5.45 KB
# Saved 'HD 13931' with size 2.05 KB
# Saved 'Хаханьян' with size 0.74 KB
# Saved 'Павильон Арсенала' with size 2.79 KB
# Saved 'Скородное (Минская область)' with size 4.20 KB
# Saved 'Андерсон, Джеймс Томас Милтон' with size 1.46 KB
# Saved 'Сиротино (посёлок, Луганская область)' with size 1.37 KB
# Saved 'Нодзири, Хоэй' with size 0.82 KB
# Saved 'Кариуки, Джосайя Мванги' with size 9.84 KB
# Saved 'Ильзе (имя)' with size 0.97 KB
# Saved 'Линзовая антенна' with size 3.37 KB
# Saved 'Пономарёв, Владимир Иванович (артист балета)' with size 14.08 KB
# Saved 'Умарсултанов, Вахит Османович' with size 4.96 KB
# Saved 'Камышный (Костанайская область)' with size 0.53 KB
# Saved 'Улица Каманина' with size 0.58 KB
# Saved 'Шалаховское водохранилище' with size 3.05 KB
# Saved 'Межево (озеро)' with size 3.51 KB
# Saved 'E.161' with size 2.43 KB
# Saved 'Панов, Александр Андреевич' with size 2.89 KB
# Saved 'Sinraptor' with size 19.07 KB
# Saved 'Спортивная гимнастика на летних Олимпийских играх 1908 — личное многоборье' with size 2.24 KB
# Saved 'Чуюнчи (приток Такелги)' with size 1.50 KB
# Saved 'Глинка (приток Цона)' with size 1.26 KB
# Saved 'Голуби (Вологодская область)' with size 0.94 KB
# Saved 'Мукамурензи, Марсианна' with size 3.85 KB
# Saved 'Немовичи (село)' with size 0.73 KB
# Saved 'Парламентские выборы в Макао (2021)' with size 1.48 KB
# Saved 'SY Волка' with size 0.69 KB
# Saved 'Протекторат Южная Нигерия' with size 2.00 KB
# Saved 'Байдиков, Василий Иванович' with size 2.06 KB
# Saved 'Огражден' with size 0.68 KB
# Saved 'Ibiza Bar' with size 2.77 KB
# Saved 'Раяты' with size 1.55 KB
# Saved 'ФК ЦСКА Москва в сезоне 1986' with size 0.76 KB
# Saved 'Олонецкая добровольческая армия' with size 4.62 KB
# Saved 'Григорьев, Георгий Степанович' with size 7.83 KB
# Saved 'Набережночелнинский институт КФУ' with size 6.33 KB
# Saved 'Брага, Франсиско' with size 4.16 KB
# Saved 'Пельтье, Тереза' with size 5.09 KB
# Saved 'Индивидуальный бренд' with size 6.80 KB
# Saved 'Обломок империи' with size 7.16 KB
# Saved 'Турсунов, Жаныбек Жумалиевич' with size 2.46 KB
# Saved 'Aim and Ignite' with size 4.43 KB
# Saved 'Подчашие' with size 2.50 KB
# Saved 'Рижская телебашня' with size 9.07 KB
# Saved 'Мухаммади-Малаери, Мухаммад' with size 4.91 KB
# Saved 'Речевая кинестезия' with size 0.89 KB
# Saved 'Чируха (приток Северной Двины)' with size 1.44 KB
# Saved 'Единицы измерения массы' with size 10.63 KB
# Saved 'Кореферентность' with size 6.04 KB
# Saved 'Кубок Кларка' with size 3.06 KB
# Saved 'The March Violets' with size 8.07 KB
# Saved 'Слана (приток Коппера)' with size 1.32 KB
# Saved 'Отношение масса/светимость' with size 2.78 KB
# Saved 'Анабаптистский талер' with size 3.08 KB
# Saved 'Эскудеро, Стэнли' with size 0.86 KB
# Saved 'Сукре (штат)' with size 0.51 KB
# Saved 'Крогаспе' with size 0.50 KB
# Saved 'Активатор апоптоза harakiri' with size 2.87 KB
# Saved 'Кун Сянси' with size 2.84 KB
# Saved 'Широков, Виктор Павлович' with size 9.56 KB
# Saved 'Липенка (Тверская область)' with size 2.34 KB
# Saved 'Oniromyia' with size 5.18 KB
# Saved 'Российский физиологический журнал имени И. М. Сеченова' with size 6.49 KB
# Saved 'Ней (Хунсрюк)' with size 0.48 KB
# Saved 'Терра Нова (экспедиция)' with size 172.19 KB
# Saved 'Набеляк, Людовик' with size 3.40 KB
# Saved 'Three (серия комиксов)' with size 1.74 KB
# Saved 'Брин, Гари' with size 2.62 KB
# Saved 'Конрад (озеро)' with size 4.56 KB
# Saved 'Красноподолье' with size 0.80 KB
# Saved 'Иванов, Пётр Андреевич (генерал)' with size 5.02 KB
# Saved 'Левчуновское сельское поселение' with size 0.71 KB
# Saved 'Ахметшина, Айгуль Гайсовна' with size 12.54 KB
# Saved 'Бромид платины(III)' with size 1.49 KB
# Saved 'Перенежье' with size 2.66 KB
# Saved 'Silent Hunter IV' with size 2.90 KB
# Saved 'Шалимята' with size 2.03 KB
# Saved 'Воймежный' with size 2.37 KB
# Saved 'Пивка (Архангельская область)' with size 1.03 KB
# Saved 'Айхенвальд, Александр Юльевич' with size 2.87 KB
# Saved 'Дарьганга' with size 1.24 KB
# Saved 'Жакказ, Стефани' with size 0.22 KB
# Saved 'Ким Дэ Ик' with size 0.87 KB
# Saved 'Тычкино (Баганский район)' with size 0.52 KB
# Saved 'Шуберт, Маркус' with size 3.21 KB
# Saved 'Рефлексация пратюркского -d- по языковым группам' with size 12.76 KB
# Saved 'Дакр, Уильям, 3-й барон Дакр из Гисленда' with size 1.28 KB
# Saved 'Вилкова, Нина Григорьевна' with size 3.94 KB
# Saved 'Никольское (Панинский район)' with size 1.60 KB
# Saved 'Шумиленки' with size 2.38 KB
# Saved 'EPOS (компьютер)' with size 6.39 KB
# Saved 'Усть-Кульское муниципальное образование' with size 0.92 KB
# Saved 'Мексикано-туркменские отношения' with size 1.85 KB
# Saved 'Пугачёв, Михаил' with size 0.37 KB
# Saved 'Slash (альбом)' with size 6.21 KB
# Saved 'Кожевников, Павел Андреевич' with size 2.21 KB
# Saved 'Мазурин, Алексей' with size 0.38 KB
# Saved 'Сёмжа' with size 0.41 KB
# Saved 'Кульвец, Абрахам' with size 5.25 KB
# Saved 'Самойлов, Алексей Васильевич' with size 1.72 KB
# Saved 'Егорлыкский историко-краеведческий музей' with size 4.27 KB
# Saved 'Fantastic' with size 0.36 KB
# Saved 'Peter, Sue & Marc' with size 3.62 KB
# Saved 'RTBF' with size 12.14 KB
# Saved 'Секс ради выживания (фильм)' with size 7.43 KB
# Saved 'Кобела, Дорота' with size 3.22 KB
# Saved 'Реймсское Евангелие' with size 26.70 KB
# Saved 'Саутгемптон (аэропорт)' with size 10.32 KB
# Saved 'Барраль, Давид' with size 4.89 KB
# Saved 'Вишеград (Болгария)' with size 0.86 KB
# Saved 'Янссон, Руне' with size 3.52 KB
# Saved 'Кале-2 (кантон)' with size 2.78 KB
# Saved 'Маньга (значения)' with size 0.33 KB
# Saved 'Мужская голова в профиль' with size 6.58 KB
# Saved 'Здравствуй, папа, Новый год!' with size 7.79 KB
# Saved 'Убийство Шамиля Одаманова' with size 30.92 KB
# Saved 'Эксабайт' with size 0.61 KB
# Saved 'Джули Бишоп (актриса)' with size 2.24 KB
# Saved 'QRP' with size 4.36 KB
# Saved 'Раудкембингур' with size 3.39 KB
# Saved 'Блатец (община Виница)' with size 2.14 KB
# Saved 'Нижняя Кийма' with size 0.65 KB
# Saved 'Пору' with size 0.98 KB
# Saved 'Перцевка' with size 0.39 KB
# Saved 'Завадкина, Екатерина Игоревна' with size 2.74 KB
# Saved 'Институт истории, языка и литературы УНЦ РАН' with size 11.36 KB
# Saved 'Комфортабельность' with size 0.33 KB
# Saved 'ТШУ' with size 0.28 KB
# Saved 'Колотовкин, Вячеслав Геннадьевич' with size 5.73 KB
# Saved 'Романов, Михаил Платонович' with size 8.15 KB
# Saved 'Эпизод с задницей' with size 8.26 KB
# Saved 'Мужская сборная Чехословакии по баскетболу' with size 3.83 KB
# Saved 'Луговой (Оренбургская область)' with size 0.77 KB
# Saved 'Скрипка (фильм, 2005)' with size 4.11 KB
# Saved 'Совгаванская ТЭЦ' with size 9.29 KB
# Saved 'Волейбол на летней Спартакиаде народов СССР 1971 (женщины)' with size 3.62 KB
# Saved 'Максуд Герай' with size 3.17 KB
# Saved 'Брагин, Василий Ефимович' with size 5.00 KB
# Saved 'Ахромеи' with size 3.56 KB
# Saved 'Шук, Вальтер' with size 6.73 KB
# Saved 'Игилик (Акмолинская область)' with size 1.43 KB
# Saved 'Пушкино (Черниговская область)' with size 0.65 KB
# Saved 'Чемпионат мира по бобслею и скелетону 2024' with size 1.36 KB
# Saved 'Каниве, Шарль-Альфред' with size 1.29 KB
# Saved 'Кординг, Гарри' with size 3.25 KB
# Saved 'Патронат (Древний Рим)' with size 3.29 KB
# Saved 'Диазоксид' with size 1.81 KB
# Saved 'Кнорринг, Иван Фёдорович (педагог)' with size 2.64 KB
# Saved 'Легенда (фильм, 2014)' with size 19.90 KB
# Saved 'ФК «Барселона» в сезоне 2008/2009' with size 4.48 KB
# Saved 'Мартинш' with size 2.01 KB
# Saved 'Вдовицын, Сергей Павлович' with size 1.82 KB
# Saved 'Султанбаево' with size 0.73 KB
# Saved 'Золотарёва, Юлия Фёдоровна' with size 3.15 KB
# Saved 'Лорка Депортива' with size 30.53 KB
# Saved 'Калмуратов, Конур' with size 1.97 KB
# Saved 'Уэллс, Адам, 1-й барон Уэллс' with size 1.27 KB
# Saved 'Шоппе, Мартин' with size 0.80 KB
# Saved 'Феррейра ду Амарал, Жуан Мария' with size 4.31 KB
# Saved 'Чёртов камень (Пирукиви)' with size 2.88 KB
# Saved 'Милавин, Борис Васильевич' with size 2.90 KB
# Saved 'Убико, Хорхе' with size 3.75 KB
# Saved 'Мата, Хуан' with size 14.86 KB
# Saved 'Желдыбай' with size 1.02 KB
# Saved 'Златка дымчатая' with size 3.06 KB
# Saved 'Дубовская, Ольга Александровна' with size 4.16 KB
# Saved 'Nissan Primera' with size 14.48 KB
# Saved 'Новый Южный Уэльс' with size 45.93 KB
# Saved 'Кременчуг-Константиновское' with size 8.97 KB
# Saved 'Круглов, Виктор' with size 0.44 KB
# Saved 'Birth of a New Age' with size 2.75 KB
# Saved 'Референдум в Дании (2022)' with size 8.58 KB
# Saved 'Симеизская обсерватория' with size 12.56 KB
# Saved 'Витебский завод радиодеталей «Монолит»' with size 5.87 KB
# Saved 'Airbus Helicopters H215' with size 47.03 KB
# Saved 'Кошерово' with size 2.50 KB
# Saved 'Бородавчатка' with size 6.65 KB
# Saved 'Утулькалама' with size 0.67 KB
# Saved 'Елец-андруга' with size 1.50 KB
# Saved 'Хардинг (город, Миннесота)' with size 0.47 KB
# Saved 'Современное пятиборье на летних Олимпийских играх 1924' with size 1.49 KB
# Saved 'Урбани, Джулиано' with size 4.20 KB
# Saved 'Деви-махатмья' with size 4.40 KB
# Saved 'Ринолит' with size 3.07 KB
# Saved 'Селенид церия' with size 1.22 KB
# Saved 'Сильный Ганс' with size 7.58 KB
# Saved 'Магмас' with size 1.07 KB
# Saved 'Чемпионат Марокко по футболу 1999/2000' with size 0.64 KB
# Saved 'Чухломино' with size 2.83 KB
# Saved 'Турсунбаев, Азизбек Атакозуевич' with size 3.88 KB
# Saved 'Введенский, Александр Петрович (протоиерей)' with size 4.18 KB
# Saved 'Гордеевы' with size 5.21 KB
# Saved 'Northrop HL-10' with size 2.94 KB
# Saved 'Вифинский полуостров' with size 4.62 KB
# Saved 'Ред-Девил (аэропорт)' with size 0.87 KB
# Saved 'Нерон и Агриппина (фильм)' with size 2.00 KB
# Saved 'Вульковский сельсовет' with size 0.38 KB
# Saved 'Баллистическая ракета' with size 13.31 KB
# Saved 'It’s Now or Never (песня)' with size 3.87 KB
# Saved 'Дендрерпетон' with size 1.97 KB
# Saved 'Тилтротатор' with size 2.24 KB
# Saved 'Арфа' with size 10.38 KB
# Saved 'Оден, Мишель' with size 28.98 KB
# Saved 'Сражение за Сан-Педро-де-лас-Колониас' with size 8.66 KB
# Saved 'Передача электроэнергии' with size 8.42 KB
# Saved 'Агоний' with size 0.48 KB
# Saved 'Спор о методах' with size 8.05 KB
# Saved 'Ордынка' with size 0.65 KB
# Saved 'Шеланы' with size 1.21 KB
# Saved 'Слотен' with size 0.40 KB
# Saved 'PPP' with size 0.52 KB
# Saved 'Травницкая хроника' with size 6.22 KB
# Saved 'Вьяна-де-Сега' with size 0.65 KB
# Saved 'Нижняя Кузью (приток Малой Визинги)' with size 1.26 KB
# Saved 'Красников, Геннадий Николаевич' with size 8.60 KB
# Saved 'Аладьин, Михаил Алексеевич' with size 4.51 KB
# Saved 'Эллаговая кислота' with size 5.08 KB
# Saved 'Ковач, Джо' with size 3.52 KB
# Saved 'Tenné' with size 6.97 KB
# Saved 'Минь' with size 1.50 KB
# Saved 'Австралийско-южносуданские отношения' with size 3.51 KB
# Saved 'Рапей, Юлия' with size 2.30 KB
# Saved 'Больше, чем игра' with size 0.16 KB
# Saved 'Старки Тайгретт, Морин' with size 9.16 KB
# Saved 'Агео' with size 1.90 KB
# Saved 'Нгуен Минь Фыонг' with size 1.84 KB
# Saved 'Концертино' with size 0.71 KB
# Saved 'Взрыв отеля Brinks' with size 9.64 KB
# Saved 'Лассаль, Антуан Шарль Луи' with size 22.60 KB
# Saved 'Пинаколиловый спирт' with size 1.08 KB
# Saved 'Омару (река)' with size 2.04 KB
# Saved 'Айдаев' with size 0.47 KB
# Saved 'Сулаберидзе' with size 0.52 KB
# Saved 'Спор о трёх главах' with size 95.11 KB
# Saved 'Редин, Семён Афанасьевич' with size 2.05 KB
# Saved 'Корман, Мануэла' with size 1.41 KB
# Saved 'Табакова, Цветана' with size 2.75 KB
# Saved 'Сплайсинг белков' with size 2.37 KB
# Saved 'Crassula sieberiana' with size 3.13 KB
# Saved 'Ле Со, Йорик' with size 2.92 KB
# Saved 'Сульфат (станция)' with size 1.08 KB
# Saved 'Список знаменосцев Ботсваны на Олимпийских играх' with size 0.40 KB
# Saved '12 of His Biggest Hits' with size 2.53 KB
# Saved 'Кымпия-Турзий' with size 0.68 KB
# Saved 'Познанский договор' with size 1.94 KB
# Saved 'Коэнред' with size 1.56 KB
# Saved 'Косгей, Бриджид' with size 6.26 KB
# Saved 'Храм Непорочного Сердца Пресвятой Девы Марии (Кемерово)' with size 2.40 KB
# Saved 'Болтич, Симо' with size 4.14 KB
# Saved 'Головкин, Василий' with size 0.48 KB
# Saved 'Земные токи' with size 5.57 KB
# Saved 'Джордж, Лесли-Энн' with size 1.68 KB
# Saved 'Чернавка (Бурлинский район)' with size 0.46 KB
# Saved 'Зелёный Листок' with size 0.36 KB
# Saved 'Дискография Lil’ Kim' with size 0.87 KB
# Saved 'Депортиво Сан-Фернандо' with size 0.77 KB
# Saved 'За канделябрами' with size 11.67 KB
# Saved 'Острая перемежающаяся порфирия' with size 4.99 KB
# Saved 'Хримлян, Арменак Иванович' with size 2.90 KB
# Saved 'Огуреева, Галина Николаевна' with size 7.46 KB
# Saved 'Боливийский ревун' with size 0.99 KB
# Saved 'Дугушев, Ахмед Адамович' with size 1.15 KB
# Saved 'Германия на Всемирных играх' with size 1.05 KB
# Saved 'Ашер, Джон Палмер' with size 4.38 KB
# Saved 'Моральное убеждение' with size 8.30 KB
# Saved 'Восточное (Крым)' with size 14.37 KB
# Saved 'Рулле-Сент-Эстеф' with size 2.53 KB
# Saved 'Написание' with size 0.43 KB
# Saved 'Зайцев, Олег Тимофеевич' with size 2.69 KB
# Saved 'Случь (приток Горыни)' with size 2.29 KB
# Saved 'Колокольников, Виктор Иванович' with size 12.10 KB
# Saved 'Хек, Джозеф Джон' with size 1.68 KB

# %%
import os
import requests
from zipfile import ZipFile
import shutil
from google.colab import drive
from google.colab import files

# Mount Google Drive to access the existing folder
drive.mount('/content/drive')

def fetch_wikipedia_page(title, lang='ru'):
    """
    Fetch a Wikipedia page content using the Wikipedia API.

    Args:
    - title: Title of the Wikipedia page (in Russian).
    - lang: Language of Wikipedia to fetch data from (default: 'ru' for Russian).

    Returns:
    - A string containing the page content, or None if the page is not found.
    """
    url = f'https://{lang}.wikipedia.org/w/api.php'
    params = {
        'action': 'query',
        'format': 'json',
        'prop': 'extracts',
        'explaintext': True,
        'titles': title
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        pages = data['query']['pages']
        page = next(iter(pages.values()))  # Get the first (and only) page result

        if 'extract' in page:
            return page['extract']
        else:
            return None
    else:
        return None

def save_page_content(title, content, folder):
    """
    Save the Wikipedia page content to a .txt file named after the title.

    Args:
    - title: Title of the Wikipedia page.
    - content: Text content to be saved.
    - folder: Folder where the .txt file will be saved.
    """
    safe_title = title.replace("/", "_").replace("\\", "_")
    file_path = os.path.join(folder, f"{safe_title}.txt")

    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(content)

    # Get the file size in kilobytes (KB)
    file_size = os.path.getsize(file_path) / 1024  # Convert to KB
    print(f"Saved '{title}' with size {file_size:.2f} KB")

def scrape_wikipedia_titles(titles, folder):
    """
    Scrape a list of Wikipedia titles and save their content to text files.

    Args:
    - titles: List of Wikipedia page titles to scrape.
    - folder: Folder where the .txt files will be saved.
    """
    if not os.path.exists(folder):
        os.makedirs(folder)  # Create folder if it doesn't exist

    # Get list of already existing files (to avoid duplicates)
    existing_files = {file.replace(".txt", "") for file in os.listdir(folder) if file.endswith(".txt")}

    for title in titles:
        if title not in existing_files:  # Only scrape if the title is not already present
            content = fetch_wikipedia_page(title)
            if content:
                save_page_content(title, content, folder)
        else:
            print(f"'{title}' already exists, skipping...")

def generate_random_titles(num_titles=30000, lang='ru'):
    """
    Fetch a list of random Wikipedia page titles from the given language Wikipedia.

    Args:
    - num_titles: Number of random titles to fetch.
    - lang: Language code for Wikipedia (default is 'ru' for Russian).

    Returns:
    - List of random Wikipedia titles.
    """
    titles = []
    url = f'https://{lang}.wikipedia.org/w/api.php'

    for _ in range(num_titles // 50):  # Wikipedia's API provides up to 50 random titles per request
        params = {
            'action': 'query',
            'format': 'json',
            'list': 'random',
            'rnlimit': 50,
            'rnnamespace': 0  # Limit to main namespace (articles only)
        }

        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            random_titles = [item['title'] for item in data['query']['random']]
            titles.extend(random_titles)

    # Return unique titles to avoid duplicates
    return list(set(titles))

# Main script execution
if __name__ == "__main__":
    # Path to the existing folder in Google Drive
    drive_folder = "/content/drive/My Drive/wikipedia_ru_data_30000"

    # Generate 3000 unique random Russian Wikipedia titles
    random_titles = generate_random_titles(30000)

    # Scrape the pages and save only new content
    scrape_wikipedia_titles(random_titles, drive_folder)

    # Zip the folder with new files
    shutil.make_archive('wikipedia_ru_data_new', 'zip', drive_folder)

    # Download the zipped folder to your local machine
    files.download('wikipedia_ru_data_new.zip')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved 'Сирийские арабские вооружённые силы' with size 34.43 KB
# Saved 'Пеньковый мост' with size 3.01 KB
# Saved '145-й меридиан' with size 0.27 KB
# Saved 'Ерошкин, Валентин Кириллович' with size 5.51 KB
# Saved 'Абду Джалол' with size 4.41 KB
# Saved 'Союз молдаван в Приднестровье' with size 3.23 KB
# Saved 'Карталспор' with size 1.01 KB
# Saved 'Калабритто' with size 0.73 KB
# Saved 'Дьяконов, Пётр Иванович' with size 9.75 KB
# Saved 'БМ-24Т' with size 2.71 KB
# Saved 'Hanma Technology' with size 4.72 KB
# Saved 'Пожвинское сельское поселение' with size 4.39 KB
# Saved 'Финские наследственные заболевания' with size 6.01 KB
# Saved 'Зуев, Дмитрий' with size 0.57 KB
# Saved 'Варшавчик' with size 1.01 KB
# Saved 'Кондратенко, Иван Тимофеевич' with size 3.06 KB
# Saved 'Пырей ковылелистный' with size 4.07 KB
# Saved 'Глен-Рок' with size 0.39 KB
# Saved 'The Best of Carmen McRae' with size 2.06 KB
# Saved 'Каули' with size 1.05 KB
# Saved 'Веласкес, Игнасио' with size 1.48 KB
# Saved 'Федеральный научный центр исследований и разработки иммунобиологических препаратов имени М. П. Чумакова РАН' with size 8.87 KB
# Saved 'Теорема Кука о двусторонних автоматах' with size 4.70 KB
# Saved 'Список богатейших людей США (1918)' with size 2.47 KB
# Saved 'Рахманово (Нижегородская область)' with size 0.47 KB
# Saved 'Спасо-Преображенский собор (Выборг)' with size 5.89 KB
# Saved 'Apalonia semiopaca' with size 2.16 KB
# Saved 'Саймон, Гарри (боксёр)' with size 5.20 KB
# Saved 'Отрасль экономики' with size 4.61 KB
# Saved 'Власта Смолакова' with size 5.74 KB
# Saved 'Сговио, Томас Иосифович' with size 7.17 KB
# Saved 'Спящий космический корабль' with size 9.25 KB
# Saved 'Десницкая, Агния Васильевна' with size 6.59 KB
# Saved '1988 год в театре' with size 3.02 KB
# Saved 'Платинагафний' with size 1.64 KB
# Saved 'Тиченор, Бриджет' with size 7.78 KB
# Saved 'Сетка' with size 1.57 KB
# Saved 'Приход к власти маршала Петена' with size 13.02 KB
# Saved 'Хранилище данных' with size 9.94 KB
# Saved 'Сугурбай' with size 0.66 KB
# Saved 'Бранкати, Виталиано' with size 2.66 KB
# Saved 'Безумие: Признания некрофила' with size 7.27 KB
# Saved 'Томпуда' with size 2.39 KB
# Saved 'Кондулис, Спирос' with size 6.65 KB
# Saved 'Франческо ди Салуццо' with size 4.21 KB
# Saved 'Чемпионат мира по конькобежному спорту в классическом многоборье 1983' with size 1.21 KB
# Saved 'За пределами понедельников' with size 1.90 KB
# Saved 'Аццано-Дечимо' with size 0.78 KB
# Saved 'Перунь' with size 5.22 KB
# Saved 'Ханкэуць' with size 0.59 KB
# Saved 'Ключищи (Княгининский район)' with size 2.00 KB
# Saved 'Дорогая Шуша 2023' with size 2.54 KB
# Saved 'Петрушино (Будинское сельское поселение)' with size 2.09 KB
# Saved 'Искровка (Полтавская область)' with size 1.52 KB
# Saved 'Международный союз по изучению четвертичного периода' with size 11.74 KB
# Saved 'Ставицкий, Юрий Иванович' with size 6.49 KB
# Saved 'Соболиная (приток Заячьей)' with size 1.01 KB
# Saved 'Колокольцево (Владимирская область)' with size 1.43 KB
# Saved 'Акциз на сладкие газированные напитки' with size 22.52 KB
# Saved 'Дубровка (Кричевский район)' with size 1.91 KB
# Saved 'Кралин' with size 0.51 KB
# Saved 'Дубинчик, Люси' with size 3.06 KB
# Saved 'Шагаракти-Шуриаш' with size 2.97 KB
# Saved 'BeiGene' with size 12.13 KB
# Saved 'Персей (опера)' with size 11.40 KB
# Saved 'Резчик, Пётр Харитонович' with size 1.78 KB
# Saved 'Горностаев, Андрей' with size 0.32 KB
# Saved 'Спивак, Марк Сидорович' with size 0.91 KB
# Saved 'Ланца, Козимо Дамиано' with size 6.04 KB
# Saved 'Мокшанцев, Сергей Алексеевич' with size 1.96 KB
# Saved 'Авиационные происшествия 1999 года' with size 1.77 KB
# Saved '30-й отдельный понтонно-мостовой батальон' with size 3.51 KB
# Saved 'Вороблин' with size 1.54 KB
# Saved 'Права ЛГБТ в Таджикистане' with size 7.55 KB
# Saved '2С43' with size 3.42 KB
# Saved 'Водопьяновка' with size 5.05 KB
# Saved 'Хадер, Насер' with size 8.27 KB
# Saved 'Флаг Мишкинского района (Башкортостан)' with size 4.14 KB
# Saved 'Филиппины на зимних Олимпийских играх 2014' with size 1.61 KB
# Saved 'Сингх, Руп' with size 4.52 KB
# Saved 'Киспе, Рональ' with size 4.84 KB
# Saved 'Уайтмен, Пол' with size 5.64 KB
# Saved 'Писарев, Геннадий Васильевич' with size 11.82 KB
# Saved 'Список символов штатов США (тартан)' with size 0.11 KB
# Saved 'Абдалла, Исмаил Сабри' with size 3.18 KB
# Saved 'Чхарой' with size 2.35 KB
# Saved 'Узденова, Мариям Зукаевна' with size 1.61 KB
# Saved 'Редонду' with size 1.55 KB
# Saved 'Мифы Ахеи' with size 9.24 KB
# Saved 'Тёплое (деревня, городской округ город Тула)' with size 1.49 KB
# Saved 'Берг (Нижняя Австрия)' with size 0.95 KB
# Saved 'Эффект Померанчука' with size 3.45 KB
# Saved 'Трис(дисиланил)амин' with size 1.74 KB
# Saved 'Динамика (музыка)' with size 7.54 KB
# Saved 'Кубок BC Card' with size 1.42 KB
# Saved 'Судиславль (значения)' with size 0.81 KB
# Saved 'Блайтские фигуры' with size 1.80 KB
# Saved 'Домналл мак Муйрхертайг Уа Бриайн' with size 9.00 KB
# Saved 'Mail Boxes Etc.' with size 4.32 KB
# Saved 'Ксенарх (стратег)' with size 0.59 KB
# Saved 'Хольмстрём, Карита' with size 2.32 KB
# Saved 'Аркадия (парк, Одесса)' with size 3.02 KB
# Saved 'Чуянов, Алексей Семёнович' with size 9.35 KB
# Saved 'Tell Me (песня Diddy)' with size 7.93 KB
# Saved 'Шильнебашское сельское поселение' with size 2.24 KB
# Saved 'Максюта, Юрий Иванович' with size 16.44 KB
# Saved 'КТО в Ингушетии (2023)' with size 10.89 KB
# Saved 'Лейпцигские воронята' with size 1.36 KB
# Saved 'Канадзукай' with size 3.35 KB
# Saved 'Исьянов, Равиль Ахмедуллович' with size 5.05 KB
# 'Бретт, Джон' already exists, skipping...
# Saved 'Севастопольская радиолокационная станция' with size 6.41 KB
# Saved 'Birdy (альбом)' with size 1.74 KB
# Saved 'Фридрих Карл (герцог Вюртемберг-Винненталя)' with size 4.50 KB
# Saved 'Хиндахский сельсовет (Хунзахский район)' with size 0.47 KB
# Saved 'Линевка' with size 0.97 KB
# Saved 'Adelitas Way' with size 5.97 KB
# Saved 'Бем, Дэрил' with size 4.58 KB
# Saved 'Кочетова' with size 0.85 KB
# Saved 'Марович, Йована' with size 5.33 KB
# Saved 'Список умерших в 1975 году' with size 62.57 KB
# Saved 'Юхас, Эстер' with size 1.08 KB
# Saved 'Уурэг-Нуур' with size 0.59 KB
# Saved 'Рядово (Калужская область)' with size 3.21 KB
# Saved 'Ярославская епархия (значения)' with size 0.33 KB
# Saved 'Артемьев, Иван Тимофеевич' with size 3.76 KB
# Saved 'Раевка (Каменский район)' with size 2.42 KB
# Saved 'Иван-Озеро (Забайкальский край)' with size 0.86 KB
# Saved 'Авионамс' with size 4.00 KB
# Saved 'Revolution MBT' with size 12.05 KB
# Saved 'Воронцов, Юрий Васильевич' with size 0.46 KB
# Saved 'Ользи (Новгородская область)' with size 2.42 KB
# Saved 'Колизей (группа)' with size 10.52 KB
# Saved 'Ferganoxyela sogdiana' with size 1.28 KB
# Saved 'Бронепалубные крейсера типа «Бремен»' with size 13.25 KB
# Saved 'Премия «Выбор критиков» за лучший научно-фантастический/хоррор фильм' with size 0.78 KB
# Saved 'Витаич, Анте' with size 1.65 KB
# 'Лага, Март Эрихович' already exists, skipping...
# Saved 'Дмитрий (князь брянский)' with size 12.80 KB
# Saved 'Эта Малого Пса' with size 0.86 KB
# Saved 'Зоммер-Боденбург, Ангела' with size 5.39 KB
# Saved 'Стрельба на летних Олимпийских играх 2012 — пневматический пистолет, 10 метров (мужчины)' with size 1.50 KB
# Saved 'Хутор-Бор' with size 1.94 KB
# Saved 'Лантан, Дариус' with size 1.33 KB
# Saved 'Вислововка' with size 0.63 KB
# Saved 'Сатюкова, Тамара Дмитриевна' with size 14.50 KB
# Saved 'Рыбников, Юрий' with size 0.50 KB
# Saved 'Шакпак (Костанайская область)' with size 0.70 KB
# Saved 'Danger Danger (альбом)' with size 3.25 KB
# Saved 'Усян' with size 2.00 KB
# Saved 'Белавино (Вачский район)' with size 3.33 KB
# Saved 'Конкурс молодых музыкантов «Евровидение-1998»' with size 6.88 KB
# Saved 'Михневич, Сергей Викторович' with size 0.79 KB
# Saved 'Уоссон, Крейг' with size 2.34 KB
# Saved 'Ревность (фильм)' with size 2.98 KB
# Saved 'Буряков, Сергей Константинович' with size 10.12 KB
# Saved 'Крашенинников, Сергей Юрьевич' with size 4.95 KB
# Saved 'Степовое (Оратовский район)' with size 0.78 KB
# Saved 'Виктурина' with size 0.36 KB
# Saved 'Венкстерн, Татьяна Владимировна' with size 4.92 KB
# Saved 'Хьюстон, Сэм' with size 11.74 KB
# Saved 'Норман, Майкл' with size 6.17 KB
# Saved 'Фермионная струна' with size 3.91 KB
# Saved '427 год' with size 1.47 KB
# Saved 'Список захороненных в Петропавловском соборе' with size 18.01 KB
# Saved 'Янышевский сельсовет' with size 0.57 KB
# Saved 'Кейм, Теодор' with size 1.19 KB
# Saved 'Шрайбер, Берни' with size 6.85 KB
# Saved 'Снегирёв, Владимир Леонтьевич' with size 3.78 KB
# Saved 'Бытом-Бобрек' with size 0.59 KB
# Saved 'Perion Network' with size 5.38 KB
# Saved 'Никольско-Рождественская церковь' with size 2.86 KB
# Saved 'Электронный текстиль' with size 19.41 KB
# Saved 'Adobe Audition' with size 2.45 KB
# Saved 'Electrolux addisoni' with size 9.09 KB
# Saved 'Три Острова' with size 4.74 KB
# Saved 'Ван Эрсдэйл' with size 0.28 KB
# 'Салимбаев, Ахметжан Салимбаевич' already exists, skipping...
# Saved 'Мартинс-Суарис' with size 1.22 KB
# Saved 'Клинская улица (Москва)' with size 5.80 KB
# Saved 'Думный' with size 0.29 KB
# Saved 'Панчо' with size 0.62 KB
# Saved 'Zonata' with size 2.74 KB
# Saved 'Штипсдорф' with size 0.47 KB
# Saved 'The Number of the Beast (песня)' with size 3.03 KB
# Saved 'Гюмюш, Синан' with size 1.82 KB
# Saved 'Савинское (Шекснинский район)' with size 0.95 KB
# Saved 'Красная Речка (Пугачёвский район)' with size 4.82 KB
# Saved 'Конья (река)' with size 1.57 KB
# Saved 'Шацкий, Иван Петрович' with size 3.22 KB
# Saved 'Альфа Хамелеона' with size 1.15 KB
# Saved 'Смирнов, Владимир Алексеевич (бизнесмен)' with size 6.21 KB
# Saved 'Сан-Фелис-ду-Токантинс' with size 1.74 KB
# Saved 'Исландская чёрная кошачья акула' with size 2.88 KB
# Saved 'Эль-Вильяр-де-Арнедо' with size 0.81 KB
# Saved 'Блокада Алмейды' with size 6.56 KB
# Saved 'Эльяш, Марк Львович' with size 4.17 KB
# Saved 'Чолово' with size 0.36 KB
# Saved 'Красноборское городское поселение' with size 3.09 KB
# Saved 'Майдан (Емильчинский район)' with size 0.69 KB
# Saved 'Старый музыкант' with size 4.37 KB
# Saved 'Уза (приток Сожа)' with size 0.91 KB
# Saved 'Пирейский порт' with size 4.25 KB
# Saved 'Пионерский парк (значения)' with size 0.31 KB
# Saved 'Изола-Миноре' with size 2.56 KB
# Saved 'Сантор, Ирена' with size 6.32 KB
# Saved 'Дворец Национального конгресса Бразилии' with size 2.22 KB
# Saved 'Скачок Резеля' with size 112.89 KB
# Saved 'Рижская группа художников' with size 3.98 KB
# Saved '49-я стрелковая дивизия (1-го формирования)' with size 14.56 KB
# Saved 'Бенанти, Лаура' with size 3.75 KB
# Saved 'Эдер (португальский футболист)' with size 8.75 KB
# Saved 'Wilki' with size 2.89 KB
# Saved 'Трясина (фильм, 2006)' with size 2.78 KB
# Saved 'Какулидис, Георгиос' with size 7.12 KB
# Saved 'Медиу-Капибариби (микрорегион)' with size 1.09 KB
# Saved 'Каплан, Виталий Маркович' with size 2.34 KB
# Saved 'Руберунг' with size 0.92 KB
# Saved 'Иоганн Людвиг II (князь Ангальт-Цербста)' with size 0.89 KB
# Saved 'Коста, Лусио' with size 3.21 KB
# Saved 'Воловое (Львовская область)' with size 0.49 KB
# Saved 'Сомнамбула (опера)' with size 8.86 KB
# Saved 'Чалагантепе' with size 2.62 KB
# Saved 'Рождественно' with size 1.31 KB
# Saved 'Джексон, Шерри' with size 3.65 KB
# Saved 'Гамарра' with size 1.37 KB
# Saved 'Пятискатный повёрнутый бикупол' with size 3.42 KB
# Saved 'Вьеле-Гриффен, Франсис' with size 4.56 KB
# Saved 'Обершлосс (замок, Тюрингия)' with size 9.41 KB
# Saved 'Розенберг (Техас)' with size 0.56 KB
# Saved 'Kerokko Demetan' with size 2.28 KB
# Saved 'Кривля' with size 1.60 KB
# Saved 'Иоанно-Предтеченский монастырь (Кунгур)' with size 3.36 KB
# Saved 'Roewe i5' with size 3.13 KB
# Saved 'Перечеканка' with size 6.55 KB
# Saved 'Троицкая Гора (Ленинградская область)' with size 2.44 KB
# Saved 'Садовский, Андрей Дмитриевич' with size 3.40 KB
# Saved 'Симон' with size 9.91 KB
# Saved 'Вайцкин, Джошуа' with size 4.86 KB
# Saved 'Гербы Ставропольского края' with size 1.16 KB
# Saved 'Негу-Икэн (озеро)' with size 2.74 KB
# Saved 'Патараки, Сергей Александрович' with size 3.26 KB
# Saved 'Моча' with size 8.98 KB
# Saved 'Угаров, Вилорий Петрович' with size 2.05 KB
# Saved 'Василев, Ванцети' with size 2.82 KB
# Saved 'Минас-ду-Леан' with size 1.28 KB
# Saved 'Новый мировой порядок (политика)' with size 6.41 KB
# Saved 'Аденский Биг-Бен' with size 9.30 KB
# Saved 'Золотая цепь (фильм, 1991)' with size 1.99 KB
# Saved 'Кузьмина, Светлана' with size 0.44 KB
# Saved 'Анатомия страсти (сезон 9)' with size 1.04 KB
# Saved 'Кадлиц, Майкл' with size 1.11 KB
# Saved 'Релебактам' with size 0.43 KB
# Saved 'Лили Сент-Сир' with size 12.32 KB
# Saved 'AN/SSQ-86' with size 3.07 KB
# Saved 'Конвей, Линн' with size 1.92 KB
# Saved 'Дунга' with size 12.96 KB
# Saved 'Ташериха' with size 1.00 KB
# Saved 'Лаврадор, Жуан Фернандеш' with size 2.56 KB
# Saved 'Каскаролла' with size 1.92 KB
# Saved 'Новогригоровка (Березнеговатский район)' with size 0.78 KB
# Saved 'Ли, Танит' with size 2.10 KB
# Saved 'Бреверн, Герман фон' with size 3.60 KB
# Saved 'Маклафлин, Джон (футболист, 1987)' with size 2.73 KB
# Saved 'Say Yes to Heaven' with size 6.48 KB
# Saved 'Канов, Сергей Дмитриевич' with size 1.54 KB
# Saved 'Вигулс, Арвис' with size 4.95 KB
# Saved 'Красные ворота' with size 16.31 KB
# Saved 'Единица (алгебра)' with size 6.68 KB
# Saved 'Archaeoglenes' with size 2.27 KB
# Saved 'ФК «Интернационале» в сезоне 2004/2005' with size 2.35 KB
# Saved 'Керулен' with size 1.21 KB
# Saved 'Лансон (судно)' with size 2.95 KB
# Saved 'Поведение' with size 47.38 KB
# '6-фунтовая пушка' already exists, skipping...
# Saved 'K2-294' with size 1.18 KB
# Saved 'Лобаново (городской округ Домодедово)' with size 0.61 KB
# Saved 'Картрайт, Райан' with size 0.78 KB
# Saved 'Галерея Шака' with size 7.96 KB
# Saved 'Соловьёвка (Кировоградская область)' with size 0.68 KB
# Saved 'Гурулёв, Альберт Семёнович' with size 2.92 KB
# Saved 'TROYCA' with size 0.60 KB
# Saved 'История «Матицы словацкой»' with size 43.52 KB
# Saved 'Эммер (село)' with size 0.38 KB
# Saved 'Озгюлтекын, Зафер' with size 2.19 KB
# Saved 'Культура Квебека' with size 20.35 KB
# Saved 'Бригита, Энит' with size 4.84 KB
# Saved 'Городошный спорт на летней Спартакиаде народов СССР 1986' with size 0.81 KB
# Saved 'Тумабулак' with size 0.77 KB
# Saved 'Рождество в Нью-Мексико' with size 3.13 KB
# Saved 'Хименес, Мильтон' with size 2.52 KB
# Saved 'Кастл, Джонни (значения)' with size 0.46 KB
# Saved 'Алая цитадель' with size 6.45 KB
# Saved 'Культура Нидерландов' with size 2.82 KB
# Saved 'Симонетт, Роланд Теодор' with size 1.03 KB
# Saved 'Corus Entertainment' with size 3.99 KB
# Saved 'Ступинка (значения)' with size 0.33 KB
# Saved 'Гекуба (значения)' with size 1.38 KB
# Saved 'Рассадники' with size 0.56 KB
# Saved 'Eriotica' with size 1.70 KB
# Saved 'Орта-Карвенд' with size 2.95 KB
# Saved 'Оорт, Барт ван' with size 1.79 KB
# Saved 'Штернхель, Зеэв' with size 17.03 KB
# Saved 'Чемпионат мира по лёгкой атлетике 2022' with size 11.77 KB
# Saved 'Наволок (Новгородский район)' with size 5.66 KB
# Saved 'Биатлон на зимних Олимпийских играх 2014 — индивидуальная гонка (женщины)' with size 1.15 KB
# Saved 'Храм иконы Божией Матери «Умиление» (Северодонецк)' with size 1.43 KB
# Saved 'Итайпе' with size 1.27 KB
# Saved 'Дэниел, Сэмюел' with size 1.67 KB
# Saved 'Криворожский экономический институт' with size 4.09 KB
# Saved 'Уолнат-Лейк (тауншип, Миннесота)' with size 2.84 KB
# Saved 'Чемпионат Греции по футболу 2007/2008' with size 1.54 KB
# Saved 'Большой Арташ' with size 0.29 KB
# Saved 'Георгий Лапиф' with size 1.00 KB
# Saved 'Кэйун' with size 3.85 KB
# Saved 'Канбулат Юлдашев' with size 5.49 KB
# Saved 'Мельник, Юрий Фёдорович' with size 5.78 KB
# Saved 'Боннак, Франсуа-Арман д’Юссон' with size 8.46 KB
# Saved 'Огненные птицы' with size 2.39 KB
# Saved 'Оджерс, Джордж' with size 4.86 KB
# Saved 'Рудский' with size 0.67 KB
# Saved 'Адельгунда (значения)' with size 0.65 KB
# Saved 'Кокелл, Чарльз' with size 1.50 KB
# Saved 'Крондл, Вацлав' with size 4.05 KB
# Saved 'Александров, Пётр Алексеевич (значения)' with size 0.31 KB
# Saved 'Детоксикация' with size 17.80 KB
# Saved 'Боричевский, Иван Адамович' with size 6.26 KB
# Saved 'Домрачева' with size 0.45 KB
# Saved 'Офланс' with size 2.19 KB
# Saved 'Гродзис' with size 4.91 KB
# Saved 'Климентьевский заказник' with size 2.58 KB
# Saved 'Санта-Колома (Риоха)' with size 0.62 KB
# Saved 'Узедом (город)' with size 0.57 KB
# Saved 'Риньи (коммуна)' with size 2.04 KB
# Saved 'Белоруков' with size 0.65 KB
# Saved 'Берман, Луис' with size 1.05 KB
# Saved 'Оахака' with size 0.25 KB
# Saved 'Морайс, Пруденти ди' with size 7.16 KB
# Saved 'Аран (Библия)' with size 3.02 KB
# Saved 'Единство (значения)' with size 2.32 KB
# Saved 'Война, Алексей Дорофеевич' with size 4.61 KB
# Saved 'Афинеево' with size 0.43 KB
# Saved 'Казбегский национальный парк' with size 41.45 KB
# Saved 'Боечко, Василий Васильевич' with size 3.63 KB
# Saved 'Томпсон, Уильям (гребец)' with size 3.20 KB
# Saved 'Дустмухамедова, Кизлархон' with size 2.84 KB
# Saved 'Анализатор спектра' with size 19.46 KB
# Saved 'Военторг на Воздвиженке' with size 23.90 KB
# Saved 'Ардебильский медицинский университет' with size 3.04 KB
# Saved 'Малиа' with size 0.23 KB
# Saved 'Новая Гоголёвка' with size 0.71 KB
# Saved 'Рокетт, Отто' with size 1.71 KB
# Saved 'Советский район (Саратовская область)' with size 6.72 KB
# Saved 'Челья' with size 0.93 KB
# Saved 'Миславский, Владимир Наумович' with size 29.34 KB
# Saved 'Шимкуль' with size 1.13 KB
# Saved 'Бестужев, Пётр Александрович' with size 15.24 KB
# Saved 'Гиймен, Амеде' with size 1.31 KB
# Saved 'Сверчково (Сокольский район)' with size 0.91 KB
# Saved 'Гваякум священный' with size 2.09 KB
# Saved 'Бурбей' with size 1.91 KB
# Saved 'Староселье (Новоржевский район)' with size 1.91 KB
# Saved 'Степь-Чумыш' with size 1.07 KB
# Saved 'Артемий (Кузьмин)' with size 8.22 KB
# Saved 'Gruppo 835' with size 3.61 KB
# Saved 'Гульбердыев, Гафур' with size 1.37 KB
# Saved 'Каракольский сельский округ (Акмолинская область)' with size 1.37 KB
# Saved 'Неаполитанский язык' with size 0.84 KB
# Saved 'Бливенсторф' with size 0.52 KB
# Saved 'Магнитно-абразивная обработка' with size 25.89 KB
# Saved 'Саросека' with size 0.91 KB
# Saved 'Иван Васильевич Булгак Патрикеев' with size 3.68 KB
# Saved 'Фильтр присоединения' with size 6.62 KB
# Saved 'Австрийцы' with size 21.25 KB
# Saved 'Iole' with size 1.27 KB
# Saved 'Дукельский, Владимир Юрьевич' with size 14.07 KB
# Saved 'Веричане' with size 1.86 KB
# Saved 'Permopanorpa schucherti' with size 1.35 KB
# Saved 'Калник (значения)' with size 0.24 KB
# Saved 'Шушин' with size 0.39 KB
# Saved 'Уэллс, Мэри (певица)' with size 2.22 KB
# Saved 'Цаппендорф' with size 1.02 KB
# Saved 'Пентакварк' with size 9.01 KB
# Saved 'Портлендский японский сад' with size 2.10 KB
# Saved 'Список деталей рельефа Мимаса' with size 2.25 KB
# Saved 'Маммализация териодонтов' with size 12.61 KB
# Saved 'Абдуллаева, Гульсара Сангиновна' with size 3.62 KB
# Saved 'Lovefool (песня Twocolors)' with size 1.35 KB
# Saved 'Като, Киёми (борец)' with size 3.08 KB
# Saved '(Get A) Grip (On Yourself)' with size 10.01 KB
# Saved 'Лавров, Михаил' with size 0.73 KB
# Saved 'Деннисон (город, Миннесота)' with size 0.57 KB
# Saved 'Айви, Ройал' with size 2.05 KB
# Saved 'Мерваль' with size 1.34 KB
# Saved 'Чен, Иоланда Евгеньевна' with size 0.44 KB
# Saved 'Медицинский университет (станция метро)' with size 2.45 KB
# Saved 'Тан Вэй' with size 6.66 KB
# Saved 'M51 (значения)' with size 0.67 KB
# Saved 'Ричардс, Кайл' with size 2.54 KB
# Saved 'Кельтская мифология' with size 24.33 KB
# Saved 'Kia Combi' with size 1.49 KB
# Saved 'Церковь Благовещения на Городище' with size 7.85 KB
# Saved 'Ле Ру, Ивон' with size 2.91 KB
# Saved 'Холдинг, Роб' with size 2.03 KB
# Saved 'Генеральный штаб Вооружённых сил Республики Сербской' with size 8.59 KB
# Saved 'Кассано-Спинола' with size 1.25 KB
# Saved 'V632 Возничего' with size 0.90 KB
# Saved 'Клемешов, Юрий Николаевич' with size 1.35 KB
# Saved 'Сложный лист' with size 14.66 KB
# Saved 'Крылов, Павел' with size 0.44 KB
# Saved 'Байсарово' with size 1.83 KB
# Saved 'Фокин, Юрий Георгиевич' with size 2.76 KB
# Saved 'Хонджон' with size 0.38 KB
# Saved 'Дмитриев, Василий' with size 1.02 KB
# Saved 'Rough n’ Stripped' with size 0.45 KB
# Saved 'Кубок Америки по футболу 2015' with size 11.12 KB
# Saved 'Хельк, Николай' with size 3.97 KB
# Saved 'Idesia (значения)' with size 0.31 KB
# Saved 'Белый, Спиридон Ефимович' with size 5.86 KB
# Saved 'Ахметов, Кырым Камигалиевич' with size 4.17 KB
# Saved 'Atta' with size 11.19 KB
# Saved 'Тит Ветурий Гемин Цикурин (консул 462 года до н. э.)' with size 0.57 KB
# Saved 'Что ты мне сделаешь, когда поймаешь' with size 4.23 KB
# Saved 'Скиапарелли (марсианский кратер)' with size 3.93 KB
# Saved 'Картер, Алан Брайан' with size 1.37 KB
# Saved 'Капитан Марвел 2 (саундтрек)' with size 3.16 KB
# Saved 'Ленинский район (Севастополь)' with size 9.05 KB
# Saved 'Аселье' with size 1.01 KB
# Saved 'Конн Макшейн О’Нил' with size 6.46 KB
# Saved 'Улыбино (Новосибирская область)' with size 1.08 KB
# Saved 'Огуз-Наме' with size 8.00 KB
# Saved 'Черных, Валентин' with size 0.60 KB
# Saved 'Улица Металлистов (Тула)' with size 5.00 KB
# Saved 'Аффирмативная психотерапия' with size 1.01 KB
# Saved 'Усть-Ишимское сельское поселение' with size 2.50 KB
# Saved 'ЧМ' with size 0.15 KB
# Saved 'Эванс, Фредди' with size 1.03 KB
# Saved 'Дискография Disturbed' with size 5.97 KB
# Saved 'Чемпионат Узбекистана по футболу 2001' with size 0.73 KB
# Saved 'Flipper' with size 12.74 KB
# Saved 'Липец (община Виница)' with size 0.86 KB
# Saved 'Переходница' with size 1.85 KB
# Saved 'Оргия мёртвых' with size 3.07 KB
# Saved 'Текаб (значения)' with size 0.26 KB
# Saved 'Holy Cow, Swami!' with size 3.89 KB
# Saved 'Бузала' with size 0.93 KB
# Saved 'Future Days' with size 1.96 KB
# Saved 'RW Близнецов' with size 2.09 KB
# Saved 'Нонапразеодимтетрагаллий' with size 1.59 KB
# Saved 'Береговое (Скадовский район)' with size 0.68 KB
# Saved 'Финал Кубка европейских чемпионов 1991' with size 1.17 KB
# Saved 'Платтен (Витлих)' with size 0.49 KB
# Saved 'Машеров, Павел Миронович' with size 2.03 KB
# Saved 'Формальная спецификация' with size 1.40 KB
# Saved 'Утхара Унникришнан' with size 1.90 KB
# Saved 'Бад-Хоннеф' with size 0.95 KB
# Saved 'Топонимия Тамбовской области' with size 13.07 KB
# Saved 'Hi-Speed Jecy' with size 8.27 KB
# Saved 'Эйхенбаум, Яков Моисеевич' with size 7.54 KB
# Saved 'Серебренникова, Евгения' with size 0.30 KB
# Saved 'Чемпионат мира по лёгкой атлетике среди юниоров 2022' with size 7.88 KB
# Saved 'Фрешейринья' with size 1.35 KB
# Saved 'Ванна (посёлок)' with size 0.59 KB
# Saved 'Беседовка' with size 0.27 KB
# Saved 'Епархия Мирасема-ду-Токантинса' with size 1.82 KB
# Saved 'Эспарцет изящный' with size 1.70 KB
# Saved 'Медвенка (значения)' with size 0.48 KB
# Saved 'Нордгейм, Вильгельм-Карл Касперович' with size 7.16 KB
# Saved 'Гайсфельд' with size 0.48 KB
# Saved 'Винкельбах (значения)' with size 0.17 KB
# Saved 'Северный полюс-29' with size 1.11 KB
# Saved 'Сакулин' with size 0.55 KB
# Saved 'Церковь Рождества Христова на Песках' with size 7.40 KB
# Saved 'Memories' with size 9.44 KB
# Saved 'Кубок России по современному пятиборью 2002' with size 0.89 KB
# Saved 'Женская сборная Швейцарии по баскетболу 3×3' with size 0.94 KB
# Saved 'Кура (отвод Малки)' with size 0.72 KB
# Saved 'Фабиану, Вагней' with size 6.77 KB
# Saved 'Калорген' with size 2.48 KB
# Saved 'Ваджрасадху' with size 1.95 KB
# Saved 'Баскетболист года конференции Sun Belt' with size 3.53 KB
# Saved 'Пале-Прача' with size 0.68 KB
# Saved 'Зубарева, Мария Владимировна' with size 4.15 KB
# Saved 'Волосково (Тверская область)' with size 6.50 KB
# Saved 'Skywell' with size 5.67 KB
# Saved 'Kylix' with size 6.79 KB
# Saved 'Barrojuba' with size 2.22 KB
# Saved 'Дорога Абылая' with size 1.57 KB
# Saved 'Полонуха' with size 1.08 KB
# Saved 'Тостао (значения)' with size 0.19 KB
# Saved 'Ла-Сарса-де-Пумареда' with size 0.87 KB
# Saved 'Хохлатый желтобрюхий тиранн' with size 7.01 KB
# Saved 'Верните Рекса' with size 6.01 KB
# Saved 'Кубок африканских наций 1976 (отборочный турнир)' with size 2.57 KB
# Saved 'Магний (медицина)' with size 7.98 KB
# Saved 'Ключ 200' with size 2.94 KB
# Saved 'Сейченто' with size 65.38 KB
# Saved 'Понизовье (Вологодская область)' with size 1.22 KB
# Saved 'Трю, Ариса' with size 1.88 KB
# Saved 'Былинские (Гродненская область)' with size 0.64 KB
# Saved 'Секретарская литература' with size 5.42 KB
# Saved 'Русско-итальянское соглашение (1909)' with size 8.05 KB
# Saved 'R-дерево (структура данных)' with size 20.18 KB
# Saved 'Его игра' with size 2.76 KB
# Saved 'Бойница' with size 1.52 KB
# Saved 'Пауло Сержио (значения)' with size 1.08 KB
# Saved 'Мария да Луш Гебуза' with size 1.20 KB
# Saved 'Февраль 2020 года' with size 13.59 KB
# Saved 'Калеевский сельсовет' with size 1.46 KB
# Saved 'Северный регион' with size 0.30 KB
# Saved 'Жанасу (Костанайская область)' with size 0.71 KB
# 'Отношение (теория множеств)' already exists, skipping...
# Saved 'Пилад (значения)' with size 0.36 KB
# Saved 'Овсень' with size 16.14 KB
# Saved 'Восточный мост' with size 0.27 KB
# Saved 'Ампаро, Эли до' with size 3.87 KB
# Saved 'Огненная пора (роман)' with size 5.12 KB
# Saved 'Дзуцев, Константин Хазбиевич' with size 3.96 KB
# Saved 'Балдино (Кировская область)' with size 2.04 KB
# Saved 'Эхопраксия (роман)' with size 8.03 KB
# Saved 'Киселёво (Можайский район)' with size 1.23 KB
# Saved 'Фанк, Терри' with size 28.41 KB
# Saved '1794 год' with size 10.53 KB
# Saved 'Андерлехт (значения)' with size 0.28 KB
# Saved 'Тургай (Костанайская область)' with size 3.08 KB
# Saved 'М. Швейцер' with size 0.26 KB
# Saved 'Otacilia ambon' with size 1.38 KB
# Saved 'Новоконстантиновка (Благоварский район)' with size 1.01 KB
# Saved 'Вик (аэропорт)' with size 1.36 KB
# Saved 'Нэш, Пол' with size 3.89 KB
# Saved 'Белл-Айлэнд' with size 9.79 KB
# Saved 'Ловина' with size 1.46 KB
# Saved 'Hertz' with size 2.34 KB
# Saved 'Поних' with size 0.34 KB
# Saved 'Лямбда Эридана' with size 4.69 KB
# Saved 'Старое (Акатовское сельское поселение)' with size 0.91 KB
# Saved '147-я стрелковая дивизия' with size 0.38 KB
# Saved 'Stigmella eiffeli' with size 2.77 KB
# Saved 'Якименко, Семён Семёнович' with size 4.56 KB
# Saved 'Беркун, Илья Моисеевич' with size 1.76 KB
# Saved 'Chrysolina costalis' with size 0.24 KB
# Saved 'Ломжа' with size 16.38 KB
# Saved 'Шайтанка (верхний приток Тары)' with size 0.87 KB
# Saved 'Умеренно-прогрессивная партия' with size 9.53 KB
# Saved 'Бернади, Стефан' with size 1.35 KB
# Saved 'Селенид плутония' with size 3.09 KB
# Saved 'Атенанго-дель-Рио' with size 0.26 KB
# Saved 'Стельмах' with size 2.34 KB
# Saved 'Разумихин, Павел Иванович' with size 7.07 KB
# Saved 'Деллавалле' with size 0.31 KB
# Saved 'Яремчук, Александр Юрьевич' with size 1.96 KB
# Saved 'Лиманчик' with size 2.32 KB
# Saved 'Львов, Семён' with size 0.13 KB
# Saved 'Симонов, Алексей Кириллович' with size 8.63 KB
# Saved 'Иваницкий, Борис Евгеньевич' with size 9.56 KB
# Saved 'Бисенский сельский округ' with size 0.41 KB
# Saved 'Исаев, Иван Исаевич' with size 2.03 KB
# Saved 'Сидорова, Ольга' with size 0.43 KB
# Saved 'Жороб' with size 1.06 KB
# Saved 'Лебедев, Евгений Владимирович' with size 0.33 KB
# Saved 'Химматзода, Мохаммадшариф' with size 2.90 KB
# Saved 'Праздник Двух Десяток' with size 1.61 KB
# Saved 'Люневиль (округ)' with size 0.97 KB
# Saved 'NGC 2183' with size 1.62 KB
# Saved 'Пантар' with size 2.60 KB
# Saved 'Ильинское (Кимрский район)' with size 7.90 KB
# Saved 'Чудеса инженерии' with size 2.02 KB
# Saved 'Гибсон, Вайолет' with size 4.33 KB
# 'Заозерское сельское поселение' already exists, skipping...
# Saved 'Дуцзи' with size 2.03 KB
# Saved 'Cruriraja parcomaculata' with size 3.64 KB
# Saved 'Летковщина' with size 0.32 KB
# Saved 'Верх-Ирмень' with size 8.69 KB
# Saved 'Франшвиль (Мёрт и Мозель)' with size 1.60 KB
# Saved 'Лома-Бланка (Чиуауа)' with size 0.75 KB
# Saved 'Мигачево (Тверская область)' with size 2.64 KB
# Saved 'Новометелкина' with size 0.56 KB
# Saved 'Люпин узколистный' with size 4.51 KB
# Saved 'Пустоши (Московская область)' with size 3.14 KB
# Saved 'Акароспора' with size 3.28 KB
# Saved 'Ивановский, Василий Семёнович' with size 7.08 KB
# Saved 'Daihatsu Wake' with size 2.95 KB
# Saved 'Злоумышленница' with size 3.12 KB
# Saved 'На Басманной (театр)' with size 9.50 KB
# Saved '10-й полк линейной пехоты' with size 7.67 KB
# Saved '218-й танковый полк' with size 1.41 KB
# Saved 'Заречье (Бабаевский район)' with size 1.10 KB
# Saved 'Нейкен, Юрис' with size 3.08 KB
# Saved 'Памятник Янке Купале (Левки)' with size 1.45 KB
# Saved 'Годзинский, Жорж де' with size 4.10 KB
# Saved 'Отрей' with size 0.54 KB
# Saved 'Аникеев, Николай Петрович (геолог)' with size 6.02 KB
# Saved 'Севё' with size 2.12 KB
# Saved 'Циперметрин' with size 8.45 KB
# Saved 'В добрый час!' with size 6.58 KB
# Saved 'Восемь триграмм' with size 4.93 KB
# Saved 'Шатобриан (кантон)' with size 2.77 KB
# Saved 'Даниловка (Первомайский район)' with size 10.54 KB
# Saved 'Карьерный переулок' with size 0.36 KB
# Saved 'Вьетнамско-мьянманские отношения' with size 4.50 KB
# Saved 'Гродзец-Малы' with size 0.66 KB
# Saved 'Дворики (Кузнецкий район)' with size 1.20 KB
# Saved 'Монтесинос, Кристиан' with size 8.58 KB
# Saved 'Регби в России' with size 28.69 KB
# Saved 'Кубок России по волейболу среди женщин 2015' with size 5.12 KB
# Saved 'Паломохино' with size 3.86 KB
# Saved 'Лысянка (Николаевская область)' with size 0.50 KB
# Saved 'Тета Большого Пса' with size 0.92 KB
# Saved 'Список космических запусков СССР в 1964 году' with size 0.76 KB
# Saved 'Ельцин. Три дня в августе' with size 2.43 KB
# Saved 'Воронель, Нина Абрамовна' with size 4.24 KB
# Saved 'Ивашко, Наталья Васильевна' with size 2.44 KB
# Saved 'Кубок Азии по футболу 2004' with size 0.83 KB
# Saved 'Вёрёш' with size 0.62 KB
# Saved 'Аоре' with size 3.43 KB
# Saved 'Койвунен, Аймо' with size 10.96 KB
# Saved 'Сборная Венгрии по хоккею с шайбой' with size 14.16 KB
# Saved 'Палеопочвоведение' with size 6.68 KB
# Saved 'Полынья (река)' with size 1.07 KB
# Saved 'Мурадов, Фарман Муса оглы' with size 1.97 KB
# Saved 'Шато Виллет' with size 1.13 KB
# Saved 'Тюренков, Иван Николаевич' with size 2.26 KB
# Saved 'Жидков, Пётр' with size 0.31 KB
# Saved 'Шарбе, Август Васильевич' with size 2.60 KB
# Saved 'Песин, Яков' with size 0.46 KB
# Saved 'Чемпионат Азии по волейболу среди мужчин 1993' with size 5.94 KB
# Saved 'Сангро, Элена' with size 5.97 KB
# Saved 'Триходермин' with size 1.49 KB
# Saved 'Эйшхоффен' with size 4.20 KB
# Saved 'Бакоты' with size 1.02 KB
# Saved 'Емельянова, Олеся Владимировна' with size 7.14 KB
# Saved 'Госплан СССР' with size 55.04 KB
# Saved 'Шаронов, Геннадий Иванович' with size 1.37 KB
# Saved 'Ключёвский сельсовет (Пономарёвский район)' with size 0.74 KB
# Saved 'Жалтырколь' with size 1.11 KB
# Saved 'Nicobium' with size 0.53 KB
# Saved 'Потока' with size 0.97 KB
# Saved 'Мужской баскетбольный турнир первого дивизиона NCAA 1950' with size 29.37 KB
# Saved 'Третьяков, Николай Васильевич' with size 6.69 KB
# Saved 'Васьковское сельское поселение' with size 0.48 KB
# Saved 'Чемпионат Египта по футболу 2012/2013' with size 2.16 KB
# Saved 'Караев, Клыч' with size 2.91 KB
# Saved 'Гинайкратия' with size 1.11 KB
# Saved 'Бакаевский сельсовет' with size 0.50 KB
# Saved 'Корнилов, Николай Александрович' with size 3.16 KB
# Saved 'Выживает сильнейший' with size 7.52 KB
# Saved 'Арашенда (Мцхетский муниципалитет)' with size 1.07 KB
# Saved 'Волколаков' with size 0.57 KB
# Saved 'Рети, Пал' with size 2.17 KB
# Saved 'Зунгу, Бонгани' with size 4.98 KB
# Saved 'Чапаевка (река)' with size 7.12 KB
# Saved 'Yoo Doo Right' with size 1.55 KB
# Saved 'Кара-Сакал' with size 0.84 KB
# Saved 'Фоменко, Игорь Константинович' with size 11.59 KB
# Saved 'Интегральная показательная функция' with size 20.43 KB
# Saved 'Тимирязев, Фёдор Иванович' with size 4.85 KB
# Saved 'Чемпионат Казахстана по футболу среди женщин 2008' with size 2.51 KB
# Saved 'Ван дер Мер' with size 0.95 KB
# Saved 'Курхаус Баден-Бадена' with size 6.28 KB
# Saved 'Deutsche Flugzeug-Werke' with size 9.06 KB
# Saved 'Баджханг (район)' with size 1.13 KB
# Saved 'Петерсон, Борис Леонидович' with size 3.35 KB
# Saved 'MasterClass' with size 4.50 KB
# Saved 'Баграш-Бигринское (сельское поселение)' with size 1.17 KB
# Saved 'Арлекин (значения)' with size 3.88 KB
# Saved 'Лабич, Ллойд' with size 3.56 KB
# Saved '(1441) Бойяи' with size 0.86 KB
# Saved 'Generation' with size 1.22 KB
# Saved 'Нестеренко, Алексей Геннадьевич' with size 4.55 KB
# Saved 'Годой-Крус (значения)' with size 0.42 KB
# Saved 'Никонова, Евгения Викторовна' with size 8.11 KB
# Saved 'Корженёвская, Мария Регина' with size 0.90 KB
# Saved 'Далримпл, Хью' with size 5.43 KB
# Saved 'Делоуч, Дэррил' with size 2.43 KB
# Saved 'Акоста-и-Лара, Армандо' with size 12.46 KB
# Saved 'Бригада подводных лодок Северного флота' with size 18.24 KB
# Saved 'Апрюзесс, Фабрис' with size 2.11 KB
# Saved 'Онежский 90-й пехотный полк' with size 9.00 KB
# Saved 'Аваран' with size 4.36 KB
# Saved 'Чемпионат Европы по футболу 2016 (отборочный турнир, группа F)' with size 1.29 KB
# Saved 'Чингизтепа' with size 2.71 KB
# Saved 'Валуйск' with size 1.59 KB
# Saved 'Антимонид никеля' with size 4.00 KB
# Saved 'Виру-Нигула (волость)' with size 1.05 KB
# Saved 'Тимошовка' with size 0.64 KB
# Saved 'Хазрет Султан (мечеть)' with size 3.54 KB
# Saved 'Перекусихина, Марья Саввишна' with size 14.75 KB
# Saved 'Восточная Чед' with size 0.98 KB
# 'Холмогорская летопись' already exists, skipping...
# Saved 'Соколов-Каминский, Аркадий Андреевич' with size 11.80 KB
# Saved 'Мнушкина, Ариана Александровна' with size 4.79 KB
# Saved 'Фогельклу, Эмилия' with size 5.16 KB
# Saved 'Питке-Мяки' with size 3.20 KB
# Saved 'Юри (жанр)' with size 8.27 KB
# Saved 'Архангельское (Глазуновский район)' with size 0.95 KB
# Saved 'Сборная Франции по футболу (до 20 лет)' with size 1.53 KB
# Saved 'Главное здание Университетского колледжа Лондона' with size 6.29 KB
# Saved 'Чемпионат СССР по футболу 1945 (первая группа)' with size 0.77 KB
# Saved 'Харпер, Артур' with size 5.09 KB
# Saved 'Бугузун (перевал)' with size 2.20 KB
# Saved 'Убийство по книге' with size 9.78 KB
# Saved 'Воздвиженская церковь (Перелазы)' with size 1.97 KB
# Saved 'Станционная улица (Москва)' with size 5.44 KB
# Saved 'Корреспондент (журнал)' with size 3.62 KB
# Saved 'Чулпан (Чистопольский район)' with size 0.79 KB
# Saved 'Днестровский каньон' with size 3.31 KB
# Saved 'Краснопартизанский район (Оренбургская область)' with size 1.12 KB
# Saved 'Хощно (значения)' with size 0.32 KB
# Saved 'Ванашимахи (Буйнакский район)' with size 1.16 KB
# Saved 'Надычи' with size 0.49 KB
# Saved 'Сен-Севе-Кальвадос' with size 1.44 KB
# Saved 'Обсерватория Маунт-Стромло' with size 8.66 KB
# Saved 'Панов, Николай Иванович' with size 0.29 KB
# Saved 'Консольный кабель' with size 1.95 KB
# Saved 'Савинский (Татарстан)' with size 0.83 KB
# Saved 'Энони' with size 6.87 KB
# Saved 'Дубинин, Виктор Иванович' with size 6.05 KB
# Saved 'Гюльмамедов, Имран Гумбат оглы' with size 6.18 KB
# Saved 'PDCD5' with size 3.32 KB
# Saved 'Улица Серышева (Хабаровск)' with size 6.25 KB
# Saved 'Эгидио да Витербо' with size 4.01 KB
# Saved 'Гусарниково' with size 2.91 KB
# Saved 'Misfit Kid' with size 1.80 KB
# Saved 'Милиционар' with size 1.51 KB
# Saved 'Техасские рейнджеры' with size 10.04 KB
# Saved 'Старк (округ)' with size 0.63 KB
# Saved 'Беда, Славко' with size 2.00 KB
# Saved 'Кодирование звуковой информации' with size 24.73 KB
# Saved 'Взрыв на нефтеперерабатывающем заводе в Нигерии (2022)' with size 2.76 KB
# Saved 'Торговые отношения Ливии и ФРГ' with size 25.56 KB
# Saved 'Премия «Золотая малина» за восстановление репутации' with size 1.30 KB
# Saved 'Чайка (монумент)' with size 3.36 KB
# Saved 'Lenomyrmex costatus' with size 2.07 KB
# Saved 'Талалаева, Светлана Петровна' with size 1.68 KB
# Saved 'Бородинка (Омский район)' with size 2.89 KB
# Saved 'Пэт' with size 7.29 KB
# Saved 'Австрия (значения)' with size 0.37 KB
# Saved 'Непристойность' with size 11.92 KB
# Saved 'Мозг рассказывает. Что делает нас людьми' with size 11.06 KB
# Saved 'Козульки' with size 1.95 KB
# Saved 'Аденантос' with size 1.09 KB
# Saved 'Адышевское сельское поселение' with size 0.80 KB
# Saved 'Банги (народ)' with size 3.71 KB
# Saved 'Сальтшёбаденская обсерватория' with size 3.18 KB
# 'Сигутин, Александр Васильевич' already exists, skipping...
# Saved 'Горно-Сахране' with size 0.91 KB
# Saved '726 год' with size 2.06 KB
# Saved 'Адаптивный подход' with size 1.85 KB
# Saved 'Дедушка (значения)' with size 0.70 KB
# Saved 'Постниково (Новодугинский район)' with size 1.13 KB
# Saved 'Чистое Поле (Орловская область)' with size 0.59 KB
# Saved 'Андресполь (гмина)' with size 0.71 KB
# Saved 'Григорюк, Иван Афанасьевич' with size 6.32 KB
# Saved 'Вязовня' with size 0.71 KB
# Saved 'Пурпура' with size 3.56 KB
# Saved 'Чоргунский исар' with size 2.63 KB
# Saved 'Тохателов, Исаак Артемьевич' with size 3.41 KB
# Saved 'Кларендон (станция метро)' with size 1.56 KB
# Saved 'Степачевская' with size 0.34 KB
# Saved 'Такуаритинга' with size 1.51 KB
# Saved 'Капур, Ранбир' with size 19.90 KB
# Saved 'Загряцков, Матвей Дмитриевич' with size 11.42 KB
# Saved 'NGC 1916' with size 0.90 KB
# Saved 'Рибарица (Ловечская область)' with size 1.06 KB
# Saved 'Озолниеки (значения)' with size 0.23 KB
# Saved 'G’d Up' with size 0.89 KB
# Saved 'Унер' with size 0.59 KB
# Saved 'Кобозев, Николай Иванович' with size 15.25 KB
# Saved 'Говард, Генри Энтони' with size 1.22 KB
# Saved 'Аксёнов, Михаил' with size 0.81 KB
# Saved 'Футбол в филателии' with size 7.45 KB
# Saved 'Нижняя Песочня' with size 2.77 KB
# Saved 'Молодогвардейский' with size 0.87 KB
# Saved 'Бейсик-инглиш' with size 5.98 KB
# Saved 'Олеш' with size 0.26 KB
# Saved 'Рохо, Маркос' with size 16.69 KB
# Saved 'Гневковское княжество' with size 3.08 KB
# Saved 'Малый Майзас (посёлок)' with size 2.34 KB
# Saved 'Carnivore (программное обеспечение)' with size 19.01 KB
# Saved 'Пик, Фредерик' with size 3.94 KB
# Saved 'MDP' with size 0.41 KB
# Saved 'Злое число' with size 1.69 KB
# Saved 'Сайга (огнестрельное оружие)' with size 59.62 KB
# Saved 'Ущо' with size 1.60 KB
# Saved 'Павлина (Овсянникова)' with size 2.82 KB
# Saved 'Сборная Республики Корея по биатлону' with size 2.31 KB
# Saved 'Площадь Восстания (Казань)' with size 6.79 KB
# Saved 'Пыльцееды' with size 2.51 KB
# Saved 'Договор Тлателолько' with size 3.52 KB
# Saved 'Дюпати, Эммануэль Мерсье' with size 2.76 KB
# Saved 'Ефаново (Нижегородская область)' with size 2.35 KB
# Saved 'На суше и на море' with size 0.62 KB
# Saved 'Фагоцитоз' with size 10.85 KB
# Saved 'Тумтум' with size 0.28 KB
# Saved 'Могутов, Григорий Александрович' with size 6.03 KB
# Saved 'Багрянник Гриффита' with size 3.73 KB
# Saved 'Федоровская (Харовский район)' with size 0.76 KB
# Saved 'Мандайона' with size 0.50 KB
# Saved 'Саргон, Бретт' with size 1.00 KB
# Saved 'Лучэн' with size 0.34 KB
# Saved 'Телезе-Терме' with size 0.74 KB
# Saved 'Красногорка (Полтавская область)' with size 0.83 KB
# Saved 'Языково (Борисоглебский район)' with size 2.68 KB
# Saved 'Чечкино-Богородское' with size 11.45 KB
# Saved 'Сетчатая оболочка' with size 0.14 KB
# Saved 'Машково (Печорский район)' with size 0.64 KB
# Saved 'Бейкер, Герберт Бреретон' with size 0.98 KB
# Saved 'Абра (провинция)' with size 2.03 KB
# Saved 'Речной проезд' with size 0.34 KB
# Saved 'Математика. Поиск истины' with size 5.32 KB
# Saved 'Lookin’ for That Girl' with size 1.68 KB
# Saved 'Соннино, Сидней' with size 6.15 KB
# Saved 'Воскресенское (Антроповский район)' with size 1.09 KB
# Saved 'Рыжеголовая птица-носорог' with size 1.47 KB
# Saved 'Девлечеровы' with size 1.96 KB
# Saved 'Мельников, Павел Иванович (животновод)' with size 1.42 KB
# Saved 'Абдрахманов, Кайдар Айтжанович' with size 3.33 KB
# Saved 'Мастрантонио, Мэри Элизабет' with size 1.70 KB
# Saved 'Теймурян' with size 0.28 KB
# Saved 'Мануйлов, Марк Эммануилович' with size 2.41 KB
# Saved 'Биатлон на зимних Олимпийских играх 2022 — спринт (мужчины)' with size 1.20 KB
# Saved 'Большая Речка (приток Маромицы)' with size 1.63 KB
# Saved 'Галлахер, Джон (младший)' with size 2.02 KB
# Saved 'Колос-д' with size 1.15 KB
# Saved 'Косомыяха' with size 0.87 KB
# Saved 'Думитреску, Янку' with size 5.92 KB
# Saved 'Психротрофные бактерии' with size 2.04 KB
# Saved 'Смольная (значения)' with size 0.65 KB
# Saved 'Степановский сельсовет' with size 2.08 KB
# Saved 'Пилсудский, Пётр Павел' with size 2.59 KB
# Saved 'Обвалка мяса' with size 4.08 KB
# Saved 'Красные гауры' with size 13.13 KB
# Saved 'Чэн Ли' with size 2.69 KB
# Saved 'Мейтленд, Фредерик, 14-й граф Лодердейл' with size 4.27 KB
# Saved 'Уаллауа (Орегон)' with size 2.39 KB
# Saved 'Викандер, Стиг' with size 8.77 KB
# Saved 'Ива туполистная' with size 3.30 KB
# Saved 'Агеев, Владимир' with size 0.29 KB
# Saved 'Бергхайм (Флахгау)' with size 0.96 KB
# Saved 'Вербовка (Лугинский район)' with size 0.78 KB
# Saved 'Новолопатинский' with size 0.71 KB
# Saved 'Малиновец' with size 0.64 KB
# Saved 'Мой любимый учитель' with size 3.45 KB
# Saved '1919 год в России' with size 12.66 KB
# Saved 'The Warehouse Group' with size 25.38 KB
# Saved 'Есентемир' with size 4.40 KB
# Saved 'Рашен-Ривер' with size 3.92 KB
# Saved 'Панкратовка (Мокшанский район)' with size 2.43 KB
# Saved 'Дубна (Чеховский район)' with size 1.88 KB
# Saved 'Дачева, Деляна' with size 4.35 KB
# Saved 'Ахмад-Шах Хан' with size 3.05 KB
# Saved 'Боненштингль, Ханс' with size 1.44 KB
# Saved 'Элизабет, Грейс' with size 2.91 KB
# Saved 'Ндеру, Джон' with size 2.50 KB
# Saved 'Чемпионат Финляндии по фигурному катанию 2001' with size 1.18 KB
# Saved 'Дерлово (Орловская область)' with size 2.76 KB
# Saved 'Массоспондил' with size 4.96 KB
# Saved 'Саръю (приток Илыча)' with size 1.59 KB
# Saved 'Франклин (округ, Иллинойс)' with size 5.00 KB
# Saved 'Сачко, Александр' with size 3.59 KB
# Saved 'Медем, Карл Иоганн Фридрих фон' with size 3.98 KB
# Saved 'Воссоединение в Вене' with size 1.76 KB
# Saved 'Жимолость раннецветущая' with size 2.03 KB
# Saved 'Лебедев, Александр Николаевич' with size 0.53 KB
# Saved 'Миллер, Виктор Всеволодович' with size 4.33 KB
# Saved 'Барон де Вильерс' with size 2.71 KB
# Saved 'Чемпионат СССР по боксу 1965' with size 0.28 KB
# Saved 'Харьково (Алтайский край)' with size 0.90 KB
# Saved 'Волчевка (приток Воробьёвки)' with size 1.00 KB
# Saved 'Уинтер-Бич (Флорида)' with size 4.37 KB
# Saved 'Nordwestdeutscher Rundfunk' with size 4.82 KB
# Saved 'Керепеши' with size 6.61 KB
# Saved 'Тетрародийпентасамарий' with size 1.57 KB
# Saved 'Стеббинс (Аляска)' with size 2.31 KB
# Saved 'Феррари, Роберто (велогонщик)' with size 0.59 KB
# Saved 'Великуша' with size 1.43 KB
# Saved 'Принцип попадания и мишени' with size 5.45 KB
# Saved 'Капелль' with size 0.80 KB
# Saved 'NGC 2128' with size 1.26 KB
# Saved 'Современные технологии автоматизации' with size 4.44 KB
# Saved 'Собачий кузу' with size 4.89 KB
# Saved 'Квартет имени Стэнли' with size 2.19 KB
# Saved 'Ограничение срока правления' with size 15.32 KB
# Saved 'Росляков, Михаил' with size 0.44 KB
# Saved 'Аза-Шатене' with size 1.34 KB
# Saved 'Ирландские войны' with size 6.30 KB
# Saved 'Валуев, Пётр Андреевич' with size 4.06 KB
# Saved 'Готтшед' with size 0.52 KB
# Saved 'Ла-Гард (Вар)' with size 1.98 KB
# Saved 'Наттив, Гай' with size 1.17 KB
# Saved 'Hushmail' with size 7.76 KB
# Saved 'Попытка государственного переворота в Сан-Томе и Принсипи (2022)' with size 2.11 KB
# 'Улица Ха-Яркон' already exists, skipping...
# Saved 'Горбатый-Шуйский, Михаил Иванович Лапа' with size 3.08 KB
# Saved 'Секкез' with size 3.01 KB
# Saved 'Митчелл, Том (учёный)' with size 3.11 KB
# Saved 'Чесно-Хелль, Михаэль' with size 3.11 KB
# Saved 'Захарова, Елена Сергеевна' with size 3.55 KB
# Saved 'Из доброго в злое' with size 1.49 KB
# Saved 'Акой (Абайская область)' with size 0.87 KB
# Saved 'Вайсберг, Олег Леонидович' with size 6.43 KB
# Saved 'Тесмофории' with size 3.40 KB
# Saved '2-я гвардейская минно-торпедная авиационная дивизия ВВС ВМФ' with size 19.54 KB
# Saved 'Смоляренко, Даниил Абрамович' with size 1.44 KB
# Saved 'Mercedes-Benz W210' with size 48.74 KB
# Saved 'Сборная СНГ по футболу' with size 2.35 KB
# Saved 'Палилула (община, Белград)' with size 1.26 KB
# Saved 'You’ve Really Got a Hold on Me' with size 6.77 KB
# Saved 'Пирожкова' with size 1.02 KB
# Saved 'Второй дивизион чемпионата мира по хоккею с шайбой 2022' with size 3.76 KB
# Saved 'Список кардиналов, возведённых папой римским Пием IX' with size 20.35 KB
# Saved 'Ньюмен, Джеральд' with size 1.80 KB
# Saved 'Московка (Северо-Казахстанская область)' with size 0.52 KB
# Saved 'Боржис, Кади' with size 4.85 KB
# Saved 'Данилюк, Тарас Васильевич' with size 1.48 KB
# Saved 'Эдле де Бьер, Этьен' with size 20.59 KB
# Saved 'Маркетинговые коммуникации' with size 25.84 KB
# Saved 'Лебеда (значения)' with size 0.52 KB
# Saved 'Ватега (аэродром)' with size 2.26 KB
# Saved '1788 год в науке' with size 2.51 KB
# Saved 'Пауэлл (округ, Кентукки)' with size 3.88 KB
# Saved 'Список серий телесериала «Курт Сеит и Александра»' with size 0.64 KB
# Saved 'Клебер, Жан-Батист' with size 15.08 KB
# Saved 'Redemption' with size 1.62 KB
# Saved 'Веселящий газ (значения)' with size 0.40 KB
# Saved 'Йенсен-Мичинес, Самаль' with size 1.78 KB
# Saved 'Усаево (Сармановский район)' with size 1.25 KB
# Saved 'MachiaVillain' with size 16.16 KB
# Saved 'Сельское поселение Береговой' with size 0.46 KB
# Saved 'Крум, Паола' with size 3.77 KB
# Saved 'Локомотив-Баладжары' with size 1.62 KB
# Saved 'Полуянов, Валерий Григорьевич' with size 2.40 KB
# Saved 'Арборе, Екатерина' with size 3.24 KB
# Saved 'Светляк (значения)' with size 0.58 KB
# Saved 'Тылтынь, Мария Юрьевна' with size 3.19 KB
# Saved 'Жене, Вероник' with size 5.80 KB
# Saved 'Горка (Кичменгско-Городецкий район)' with size 1.17 KB
# Saved 'Монаков' with size 0.93 KB
# Saved 'Садовое (Предгорный район)' with size 1.55 KB
# Saved 'Признак Фабрикантова' with size 2.02 KB
# Saved 'Дружевец' with size 2.66 KB
# Saved 'Шибенско-Книнска' with size 3.36 KB
# Saved 'Санта-Мария-ин-Портико-Кампителли (титулярная диакония)' with size 6.62 KB
# Saved 'Эрарский, Анатолий Александрович' with size 10.70 KB
# Saved 'Ахиезер, Александр' with size 0.34 KB
# Saved 'Президентские выборы в Косове (2008)' with size 2.13 KB
# Saved 'Женская сборная Венгрии по хоккею с мячом' with size 0.67 KB
# Saved 'Соловей (поезд)' with size 5.02 KB
# Saved 'Дубровка (Курганская область)' with size 1.03 KB
# Saved 'Эрташ, Нешет' with size 4.44 KB
# Saved 'Четыре после полуночи' with size 3.41 KB
# Saved 'Клан Сетон' with size 10.18 KB
# Saved 'Игнатьев, Борис' with size 0.33 KB
# Saved 'Комптон, Джеймс, 3-й граф Нортгемптон' with size 6.43 KB
# Saved 'Фасоль (значения)' with size 0.21 KB
# Saved 'Грозелье, Сара Питерс' with size 2.91 KB
# Saved '11-я улица' with size 0.49 KB
# Saved 'Зиллур Рахман' with size 2.35 KB
# Saved 'Элзенга, Ян' with size 5.39 KB
# Saved 'Бентли, Джон (журналист)' with size 1.49 KB
# Saved 'Риттер, Анна' with size 4.02 KB
# Saved 'Хуляй' with size 0.79 KB
# Saved 'Мужская сборная Бразилии по волейболу' with size 24.86 KB
# Saved 'Хотинский мирный договор' with size 6.25 KB
# Saved 'Джойс, Тревор' with size 2.44 KB
# Saved 'Суперкубок Англии по футболу 1988' with size 0.86 KB
# Saved 'Самсонов, Алексей Кириллович' with size 3.04 KB
# Saved 'Покровский монастырь (Киев)' with size 10.05 KB
# Saved 'Тоша (значения)' with size 0.30 KB
# Saved 'Adidas Fevernova' with size 2.10 KB
# Saved 'Фаулья' with size 1.04 KB
# Saved 'Адриатико (стадион)' with size 1.30 KB
# Saved 'Первая лига чемпионата России по мини-футболу 2009/2010' with size 4.39 KB
# Saved 'Тарадайко, Всеволод Семёнович' with size 3.33 KB
# Saved 'On the Run Tour' with size 7.04 KB
# Saved 'Сига (значения)' with size 1.25 KB
# Saved 'Зелени (Владимирская область)' with size 1.30 KB
# Saved 'Беркутов, Александр Николаевич (генерал-майор)' with size 3.53 KB
# Saved 'Кесараци, Хачатур' with size 2.06 KB
# Saved 'Дикая бригада' with size 2.69 KB
# Saved 'Архат (буддизм)' with size 13.62 KB
# Saved 'Рамирес, Гастон' with size 7.81 KB
# Saved 'Магнус, Георг Вашингтон' with size 1.44 KB
# Saved 'Пираза' with size 3.25 KB
# Saved 'Оленьковский' with size 0.79 KB
# Saved 'Муджелло (трасса)' with size 1.74 KB
# Saved 'Касанга' with size 0.75 KB
# Saved 'Публий Сестий Капитолин Ватикан' with size 1.34 KB
# Saved 'Скелтон, Джозеф' with size 2.06 KB
# Saved 'Иванов, Аркадий' with size 0.57 KB
# Saved 'Серро-де-ла-Вига' with size 2.24 KB
# Saved 'Новая Павловка (Полтавская область)' with size 0.88 KB
# Saved 'Углицкое княжество' with size 9.87 KB
# Saved 'Анежская улица' with size 1.50 KB
# Saved 'Ястреб (Омская область)' with size 2.09 KB
# Saved 'Вильявельид' with size 0.52 KB
# Saved 'Люйиндюла, Пеги' with size 4.24 KB
# Saved 'Полевой конёк' with size 3.56 KB
# Saved 'Токката и фуга' with size 0.91 KB
# Saved 'Сувар (значения)' with size 0.74 KB
# Saved 'Мисаил Абалацкий' with size 7.75 KB
# Saved 'Дудник' with size 4.10 KB
# Saved 'Ритуальные убийства в Ярославле' with size 16.41 KB
# Saved 'Гребёнкин, Константин Фридэнович' with size 0.50 KB
# Saved 'Чужумово' with size 0.72 KB
# Saved 'Чемпионат мира по кёрлингу среди женщин 1986' with size 2.59 KB
# Saved 'Куропаткинский' with size 1.11 KB
# Saved 'Контубернал' with size 2.94 KB
# ...
# Saved 'Губино (Самарская область)' with size 0.66 KB
# Saved 'Пачепельда' with size 1.37 KB
# Saved 'Xelibri' with size 3.75 KB
# Saved 'Сверчинский, Александр Алексеевич' with size 2.88 KB
# Saved 'BD Андромеды' with size 2.01 KB
# Saved 'Паркер, Джеймс Катлер Данн' with size 2.23 KB
# Saved 'Дярла' with size 1.87 KB
# Saved 'Родригес Перейра Жуниор, Силвио' with size 1.89 KB
# Saved 'SRT Light Red Line' with size 8.07 KB
# Saved 'Fun on a Bun' with size 3.92 KB
# Saved 'Хоумас' with size 7.27 KB
# Saved 'Зубов, Пётр Алексеевич' with size 9.24 KB
# Saved 'Маломихайловский сельский совет (Покровский район)' with size 0.68 KB
# Saved 'Nvidia Tegra' with size 8.41 KB
# Saved 'Фабрично-заводские комитеты' with size 5.92 KB
# Saved 'Никольское (Брейтовский район)' with size 2.22 KB
# Saved 'Гран-при Испании 1971 года' with size 2.26 KB
# Saved 'Песковатка (железнодорожная станция, Тамбовская область)' with size 1.79 KB
# Saved 'Гипотеза культивации' with size 55.23 KB
# Saved 'Кронштадтка' with size 1.65 KB
# Saved 'Опсеница, Станко' with size 1.42 KB
# Saved 'Браге, Йорген' with size 0.21 KB
# Saved 'Официал' with size 4.69 KB
# Saved 'Тасарык' with size 0.42 KB
# Saved 'Эс-Сухне' with size 2.22 KB
# Saved 'Бернард, Фрэнсис' with size 3.07 KB
# Saved 'Парафин' with size 15.72 KB
# Saved 'Нгата, Халоти' with size 0.60 KB
# Saved 'Центризм' with size 2.08 KB
# Saved 'Бабья (Великоустюгский район)' with size 1.92 KB
# Saved 'Lifan Foison' with size 0.72 KB
# Saved 'ДНК-микрочип' with size 23.80 KB
# Saved 'Язык действий' with size 2.85 KB
# Saved 'Просёлок' with size 2.30 KB
# Saved 'Мамонов, Михаил Иванович' with size 3.97 KB
# Saved 'Савченко, Александра' with size 0.44 KB
# Saved 'Железнодорожный музей в Виланова' with size 1.55 KB
# Saved 'Хартхаузен' with size 0.48 KB
# Saved 'Таджики' with size 86.30 KB
# Saved 'Коварский, Михаил Ефимович' with size 2.13 KB
# Saved 'Торбан (значения)' with size 0.36 KB
# Saved 'Двууголка' with size 3.96 KB
# Saved 'Петраш, Ладислав' with size 2.37 KB
# Saved 'Паоло, Коннор' with size 1.46 KB
# Saved 'Бабурин, Алексей Васильевич' with size 4.92 KB
# Saved 'Клапут' with size 0.36 KB
# Saved 'Мухин, Николай Алексеевич' with size 5.07 KB
# Saved 'Селище (Трубчевский район)' with size 2.39 KB
# Saved 'Месть Звёздного Луча (Коты-Воители)' with size 19.54 KB
# Saved 'Penguin Isle' with size 5.92 KB
# Saved 'Симакан, Мохамед' with size 2.04 KB
# Saved 'Фруадконш' with size 2.08 KB
# Saved 'Восточный Тимор на летних Олимпийских играх 2020' with size 1.11 KB
# Saved 'Денисов, Валерий Сергеевич' with size 4.47 KB
# Saved 'Монастырь Бебенхаузен' with size 3.31 KB
# Saved 'Самоне' with size 0.93 KB
# Saved 'Хитоми (космический телескоп)' with size 6.02 KB
# Saved 'Флаг Тывы' with size 5.49 KB
# Saved 'Дом Толмачёвых' with size 2.49 KB
# Saved 'Бантинг, Майкл' with size 4.26 KB
# Saved 'Кремнево (Крым)' with size 10.25 KB
# Saved 'Голубая книга' with size 11.12 KB
# Saved 'Швабский Альб' with size 5.91 KB
# Saved 'Lara Croft and the Temple of Osiris' with size 5.83 KB
# Saved 'Sumer is icumen in' with size 4.66 KB
# Saved 'Jesus Christ Pose' with size 11.19 KB
# Saved 'Космическая медаль Почёта Конгресса' with size 1.81 KB
# Saved 'Кашинская, Алина Валерьевна' with size 0.97 KB
# Saved 'Юрях-Тёрдё' with size 1.12 KB
# Saved 'Ван де Донк, Даниэль' with size 7.05 KB
# Saved 'Исуатлансильо (муниципалитет)' with size 0.33 KB
# Saved 'Ийовухва-чороте' with size 0.78 KB
# Saved 'Сервиль' with size 0.73 KB
# Saved 'Озвалду-Крус' with size 1.32 KB
# Saved 'Образцов, Александр Алексеевич' with size 6.06 KB
# Saved 'Социальное поведение' with size 1.97 KB
# Saved 'Краснохвостая якамара' with size 1.59 KB
# Saved 'Стулово (Ивановская область)' with size 2.45 KB
# Saved 'Гохберг' with size 1.31 KB
# Saved 'Улица Муканова (Алма-Ата)' with size 3.97 KB
# Saved 'Scream In Darkness' with size 11.25 KB
# Saved 'Климатический оптимум' with size 8.45 KB
# Saved 'Калинеево' with size 2.11 KB
# Saved 'Хамзаев, Магомед Русланович' with size 1.78 KB
# Saved 'Сербия на «Евровидении-2010»' with size 2.37 KB
# Saved 'Парламентские выборы в Италии (1900)' with size 1.91 KB
# Saved 'Раздольненское сельское поселение (Кореновский район)' with size 1.06 KB
# Saved 'Больцано-Новарезе' with size 1.08 KB
# Saved 'Красково (Харовский район)' with size 1.00 KB
# Saved 'Триммер, Сара' with size 3.84 KB
# Saved 'Погорелов Майдан' with size 0.53 KB
# Saved 'Сосновица (Вологодская область)' with size 0.87 KB
# Saved '228-я стрелковая дивизия (1-го формирования)' with size 18.72 KB
# Saved 'Луценко, Павел Кондратьевич' with size 3.23 KB
# Saved 'Акт о преступлениях против личности (1861)' with size 2.07 KB
# Saved 'Корг' with size 12.24 KB
# Saved 'Марёй-сюр-ле-Дисе' with size 4.86 KB
# Saved 'Чемпионат четырёх континентов по фигурному катанию 2025' with size 2.05 KB
# Saved 'Хиросима (княжество)' with size 13.53 KB
# Saved 'Бей, Турхан' with size 3.58 KB
# Saved 'Ватаманюк, Гаврил' with size 9.32 KB
# Saved 'Дохтуров, Владимир Сергеевич' with size 3.21 KB
# Saved '25 сентября' with size 30.00 KB
# Saved 'Бонапарт, Каролина' with size 10.02 KB
# Saved 'Песковатка (Белгородская область)' with size 2.59 KB
# Saved 'Нижняя Каменка' with size 0.39 KB
# Saved 'Махореро' with size 7.12 KB
# Saved 'Dear Socks, Dear Buddy' with size 3.53 KB
# Saved 'Либавское восстание' with size 16.87 KB
# Saved 'Шамхал-Янги-Юрт' with size 1.55 KB
# Saved 'Голубой гасконский бассет' with size 6.74 KB
# Saved 'Йылмаз, Рейхан' with size 1.18 KB
# Saved 'Громов, Игнатий Владимирович' with size 9.31 KB
# Saved 'Бирюки (Киевская область)' with size 0.74 KB
# Saved 'Тоговщинская промзона' with size 4.36 KB
# Saved 'GSMA' with size 9.13 KB
# Saved 'Гиемпсал' with size 0.32 KB
# Saved 'А зори здесь тихие… (повесть)' with size 16.57 KB
# Saved 'Чемпионаты Азии по пауэрлифтингу' with size 0.21 KB
# Saved 'Мамедов, Рамин Алемшах оглы' with size 6.73 KB
# Saved 'Корцовское сельское поселение' with size 1.23 KB
# Saved 'Виргман, Чарльз' with size 2.93 KB
# Saved 'Святая Вероника' with size 6.73 KB
# Saved 'Герои Социалистического Труда Костанайской области' with size 4.51 KB
# Saved 'Тысяча верст' with size 2.86 KB
# Saved 'Жерновки (Рязанская область)' with size 3.28 KB
# Saved 'Сиби (значения)' with size 0.40 KB
# Saved 'Столяренко' with size 0.48 KB
# Saved 'Лужаны (Черновицкая область)' with size 2.66 KB
# Saved 'Наби, Мухаммед' with size 2.20 KB
# Saved 'Бакуви, Сейид Яхья' with size 24.57 KB
# Saved 'Resonate' with size 1.34 KB
# Saved 'Бокситогорская улица' with size 2.67 KB
# Saved 'Санта-Мария (культура)' with size 4.18 KB
# Saved 'Асаревичский сельсовет' with size 0.81 KB
# Saved 'Короча (приток Нежеголи)' with size 3.86 KB
# Saved 'Кожистая черепаха' with size 4.34 KB
# Saved 'Готлиб, Адольф (значения)' with size 0.24 KB
# Saved 'Жданова, Анна Ивановна' with size 6.15 KB
# Saved 'Ли Сончхоль' with size 1.90 KB
# Saved 'Тиоцианат золота(I)' with size 2.40 KB
# Saved 'Виттгенштайнер-Ланд' with size 28.45 KB
# Saved 'Чемпионат России по волейболу среди мужчин 2007/2008' with size 13.04 KB
# Saved 'Пише: Между небом и землёй' with size 3.57 KB
# Saved 'CD-35 16019' with size 1.67 KB
# Saved 'Непер (лунный кратер)' with size 4.41 KB
# Saved '112-й отдельный вертолётный полк' with size 2.47 KB
# Saved 'Взятие Дюнамюнде' with size 2.38 KB
# Saved 'Бутылка рома с сифоном' with size 1.34 KB
# Saved 'Понтьяк (муниципалитет)' with size 1.98 KB
# Saved 'Денежная слобода' with size 2.24 KB
# Saved 'Гофмейер, Нильс' with size 4.31 KB
# Saved 'Чапчакчи' with size 1.77 KB
# Saved 'Список графов и маркграфов Намюра' with size 4.95 KB
# Saved 'Альборнос, Аврора де' with size 4.52 KB
# Saved 'Русилово' with size 0.90 KB
# Saved 'Фосс (Франция)' with size 0.53 KB
# Saved 'Поллард, Джонатан' with size 20.61 KB
# Saved 'Иссык-Кульская котловина' with size 2.97 KB
# Saved 'Гогатадзе, Надя Александровна' with size 2.52 KB
# Saved 'Шашков, Никита Геннадьевич' with size 1.33 KB
# Saved '(623) Химера' with size 0.91 KB
# Saved 'Булгаков, Александр' with size 0.92 KB
# Saved 'Пепельный свет Луны' with size 3.32 KB
# Saved 'Мызы' with size 0.47 KB
# Saved 'Лонгвилл (город, Миннесота)' with size 0.62 KB
# Saved 'Кошницкий, Гари' with size 3.59 KB
# Saved 'Стецкий, Алексей Иванович' with size 6.36 KB
# Saved 'Такаяма (Гифу)' with size 1.91 KB
# Saved 'Бойл (Роскоммон)' with size 1.48 KB
# Saved 'Отель «Централь» (Кисловодск)' with size 3.32 KB
# Saved 'Порчия' with size 2.18 KB
# Saved 'Тищенко, Виктор Григорьевич' with size 2.70 KB
# Saved 'Роксолана (значения)' with size 0.72 KB
# Saved 'Бялик' with size 0.51 KB
# Saved 'Коллоредо, Себастьян' with size 1.79 KB
# Saved '0 января' with size 1.45 KB
# Saved 'Аполлон-14' with size 61.88 KB
# Saved 'Эбертсхайм' with size 0.56 KB
# Saved 'Онфруа (граф Апулии)' with size 7.73 KB
# Saved 'Мигуда' with size 1.54 KB
# Saved 'Аль-Мустансир Биллах II' with size 6.07 KB
# Saved 'Артемиса (значения)' with size 0.22 KB
# Saved 'Саламов, Ислам Камильевич' with size 1.00 KB
# Saved 'Айронсайд, Вирджиния' with size 4.05 KB
# Saved 'Элерс, Хайнц' with size 2.85 KB
# Saved 'Коулман, Бобби' with size 2.21 KB
# Saved 'Алексий (Сергеев)' with size 21.35 KB
# Saved 'Ураган (ядерное испытание)' with size 9.98 KB
# Saved 'Хизриев, Надирбег Халидович' with size 4.58 KB
# Saved 'Список претендентов на премию «Оскар» за лучший фильм на иностранном языке от Польши' with size 2.76 KB
# Saved 'Команда (шаблон проектирования)' with size 9.66 KB
# Saved 'Щегловский, Александр Витальевич' with size 1.81 KB
# Saved 'Границы безумия' with size 9.25 KB
# Saved 'Мулумбу, Юссуф' with size 2.55 KB
# Saved 'Кубок мира по конькобежному спорту 2008/2009 (этап 2)' with size 0.38 KB
# Saved 'Зеленская, Елена' with size 0.47 KB
# Saved 'Кромби, Алистер' with size 5.63 KB
# Saved 'Махек (значения)' with size 0.46 KB
# Saved 'Добрынин, Николай Фёдорович' with size 5.32 KB
# Saved 'Мэннинг, Даррен' with size 6.15 KB
# Saved 'Варфоломеев, Владимир Викторович' with size 4.10 KB
# Saved 'Колымская низменность' with size 3.17 KB
# Saved 'Апостол, Йоан' with size 6.72 KB
# Saved 'Лели (деревня)' with size 0.90 KB
# Saved 'Ариодант' with size 14.14 KB
# Saved 'Список Героев Советского Союза (Марий Эл)' with size 2.82 KB
# Saved 'Арзев' with size 1.12 KB
# Saved 'Мистулов, Эльмурза Асланбекович' with size 10.31 KB
# Saved 'Томский приборный завод' with size 4.20 KB
# Saved 'Низево' with size 0.94 KB
# Saved 'Милорадович, Мило' with size 3.83 KB
# Saved 'Комсомольский (Гулькевичский район)' with size 0.46 KB
# Saved 'Перепись населения Литвы (1942)' with size 0.65 KB
# Saved 'Кастрен, Урхо' with size 1.81 KB
# Saved 'Криваль' with size 0.47 KB
# Saved 'Protomyces inouyei' with size 1.05 KB
# Saved 'Цыганский овраг (Луганск)' with size 3.82 KB
# Saved 'Арский, Павел Александрович' with size 4.56 KB
# Saved 'Бернсторф' with size 0.68 KB
# Saved 'Васина Поляна' with size 0.69 KB
# Saved 'The Twisted World of Marge Simpson' with size 3.75 KB
# Saved 'Враниловци' with size 1.04 KB
# Saved 'NGC 4015-2' with size 0.85 KB
# Saved 'Караибрахимгил, Нил' with size 1.32 KB
# Saved 'Бендковице (Малопольское воеводство)' with size 2.21 KB
# Saved 'Герб Шри-Ланки' with size 1.84 KB
# Saved 'Голчаново' with size 0.32 KB
# Saved 'Самервилл, Джимми' with size 6.18 KB
# Saved 'Май Цзя' with size 10.29 KB
# Saved 'Хрома хлориды' with size 0.06 KB
# Saved 'Кларк, Марк (значения)' with size 0.31 KB
# Saved 'Аккум (Маякумский сельский округ)' with size 0.76 KB
# Saved 'Ивушкин, Владимир Иванович' with size 2.46 KB
# Saved 'Якушов, Николай Викторович' with size 1.54 KB
# Saved 'Герб Курчатова (Россия)' with size 3.47 KB
# Saved 'Спиритический сеанс (рассказ)' with size 13.79 KB
# Saved 'Пинниджер, Эрик' with size 3.40 KB
# Saved 'Цопп, Юрген' with size 2.91 KB
# Saved 'Ульянов, Дмитрий Ильич' with size 14.45 KB
# Saved 'Мирославец (гмина)' with size 0.36 KB
# Saved 'Новоспасск (Амурская область)' with size 2.57 KB
# Saved 'Иффандик' with size 4.22 KB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5d39f265fd10> in <cell line: 119>()
#     125
#     126     # Scrape the pages and save only new content
# --> 127     scrape_wikipedia_titles(random_titles, drive_folder)
#     128
#     129     # Zip the folder with new files
#
# <ipython-input-3-5d39f265fd10> in scrape_wikipedia_titles(titles, folder)
#      78     for title in titles:
#      79         if title not in existing_files:  # Only scrape if the title is not already present
# ---> 80             content = fetch_wikipedia_page(title)
#      81             if content:
#      82                 save_page_content(title, content, folder)
#
# <ipython-input-3-5d39f265fd10> in fetch_wikipedia_page(title, lang)
#      29     }
#      30
# ---> 31     response = requests.get(url, params=params)
#      32
#      33     if response.status_code == 200:
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1055         """
#    1056         if self.chunked and self.supports_chunked_reads():
# -> 1057             yield from self.read_chunked(amt, decode_content=decode_content)
#    1058         else:
#    1059             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#    1204
#    1205             while True:
# -> 1206                 self._update_chunk_length()
#    1207                 if self.chunk_left == 0:
#    1208                     break
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _update_chunk_length(self)
#    1123         if self.chunk_left is not None:
#    1124             return None
# -> 1125         line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126         line = line.split(b";", 1)[0]
#    1127         try:
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import requests
from zipfile import ZipFile
import shutil
from google.colab import drive
from google.colab import files

# Mount Google Drive to access the existing folder
drive.mount('/content/drive')

def fetch_wikipedia_page(title, lang='ru'):
    """
    Fetch a Wikipedia page content using the Wikipedia API.

    Args:
    - title: Title of the Wikipedia page (in Russian).
    - lang: Language of Wikipedia to fetch data from (default: 'ru' for Russian).

    Returns:
    - A string containing the page content, or None if the page is not found.
    """
    url = f'https://{lang}.wikipedia.org/w/api.php'
    params = {
        'action': 'query',
        'format': 'json',
        'prop': 'extracts',
        'explaintext': True,
        'titles': title
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        pages = data['query']['pages']
        page = next(iter(pages.values()))  # Get the first (and only) page result

        if 'extract' in page:
            return page['extract']
        else:
            return None
    else:
        return None

def save_page_content(title, content, folder):
    """
    Save the Wikipedia page content to a .txt file named after the title.

    Args:
    - title: Title of the Wikipedia page.
    - content: Text content to be saved.
    - folder: Folder where the .txt file will be saved.
    """
    safe_title = title.replace("/", "_").replace("\\", "_")
    file_path = os.path.join(folder, f"{safe_title}.txt")

    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(content)

    # Get the file size in kilobytes (KB)
    file_size = os.path.getsize(file_path) / 1024  # Convert to KB
    print(f"Saved '{title}' with size {file_size:.2f} KB")

def scrape_wikipedia_titles(titles, folder):
    """
    Scrape a list of Wikipedia titles and save their content to text files.

    Args:
    - titles: List of Wikipedia page titles to scrape.
    - folder: Folder where the .txt files will be saved.
    """
    if not os.path.exists(folder):
        os.makedirs(folder)  # Create folder if it doesn't exist

    # Get list of already existing files (to avoid duplicates)
    existing_files = {file.replace(".txt", "") for file in os.listdir(folder) if file.endswith(".txt")}

    for title in titles:
        if title not in existing_files:  # Only scrape if the title is not already present
            content = fetch_wikipedia_page(title)
            if content:
                save_page_content(title, content, folder)
        else:
            print(f"'{title}' already exists, skipping...")

def generate_random_titles(num_titles=100000, lang='ru'):
    """
    Fetch a list of random Wikipedia page titles from the given language Wikipedia.

    Args:
    - num_titles: Number of random titles to fetch.
    - lang: Language code for Wikipedia (default is 'ru' for Russian).

    Returns:
    - List of random Wikipedia titles.
    """
    titles = []
    url = f'https://{lang}.wikipedia.org/w/api.php'

    for _ in range(num_titles // 50):  # Wikipedia's API provides up to 50 random titles per request
        params = {
            'action': 'query',
            'format': 'json',
            'list': 'random',
            'rnlimit': 50,
            'rnnamespace': 0  # Limit to main namespace (articles only)
        }

        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            random_titles = [item['title'] for item in data['query']['random']]
            titles.extend(random_titles)

    # Return unique titles to avoid duplicates
    return list(set(titles))

# Main script execution
if __name__ == "__main__":
    # Path to the existing folder in Google Drive
    drive_folder = "/content/drive/My Drive/wikipedia_ru_data_30000"

    # Generate 3000 unique random Russian Wikipedia titles
    random_titles = generate_random_titles(100000)

    # Scrape the pages and save only new content
    time.sleep(5)  # Pause for 5 seconds

    # Scrape the pages and save only new content
    try:
        scrape_wikipedia_titles(random_titles, drive_folder)
    except OSError as e:
        print(f"Error accessing or modifying the folder: {e}")
        print("Check your Google Drive connection, permissions, and file system.")

    # Zip the folder with new files
    shutil.make_archive('wikipedia_ru_data_new10s', 'zip', drive_folder)

    # Download the zipped folder to your local machine
    files.download('wikipedia_ru_data_new10s.zip')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-503df6f72e10> in <cell line: 119>()
#     125
#     126     # Scrape the pages and save only new content
# --> 127     time.sleep(5)  # Pause for 5 seconds
#     128
#     129     # Scrape the pages and save only new content
#
# NameError: name 'time' is not defined
